# %% [markdown]
# ## Homework 1: Advanced Track -- Harvest the Twitter API

# %% [markdown]
# **Objective:** Write a series of functions that allow you to dynamically harvest Twitter data.
#
# **Estimated Time to Complete:** 4-12 hours
#
# #### Sections
#
#  - **Section 1:** Setting up your developer account, using OAuth1 authentication (approx 45-120 minutes)
#  - **Sections 2 & 3:** Navigating the API documentation, getting your first query strings (approx 45-120 minutes)
#  - **Section 3:** Writing your API calls (approx 90 - 360 minutes)
#
# #### What You'll Turn In:
#  - A `.py` (not a Notebook!) file that contains the functions that you were prompted to create.  These should contain comments demonstrating why your code does what it does, and after it's run, the instructor should be able to make the appropriate function calls in Spyder or any other IDE.

# %% [markdown]
# ## Section 1:  Setting Up Your Developer Account

# %% [markdown]
# Most API's require you to do a little pre-work in order to be able to use them, so the first part of this homework assignment will be spent setting up your developer account so you have API Access.

# %% [markdown]
# **Step 1:  Create a Twitter Developer Account**
#
#  - Make sure you have a regular twitter account before you do this
#  - You can apply for a developer account here:  https://developer.twitter.com/en/apply-for-access
#   - Choose either a student or hobbyist/personal account
#   - **note:** these typically get approved right away, but it's possible you might have to wait a little bit......if 15 minutes pass, it might be best to take a break and come back in an hour or so.

# %% [markdown]
# **Step 2:  Create An App**
#
# You don't have to intend to build an official software program to have an app.....this is just a way for you to get authentication keys to use with the API.
#
#  - Go to the menu in the upper right hand corner and click on **Your Name** > **Apps**
#  - Choose **Create An App**
#  - You'll be prompted to enter some information about your app.  Don't worry too much about this, it can say almost anything.  You'll be prompted to list websites where it will be hosted...this can be anything for now.  Use https://generalassemb.ly if you're undecided about what to put.

# %% [markdown]
# **Step 3: Create Your API Tokens**
#
# Now that you have an app, you can use its API tokens to go ahead and make requests like we did in class 3.  Like a lot of API's, the Twitter API uses something called OAuth authentication.
#
# If you didn't wait until the night before this assignment was due and have a spare 30 minutes, you can read a little about it here: https://oauth.net/
#
# In any event, you need API tokens in order to make requests.  Do the following:
#
#  - Go to the **Apps** section of your developer portal
#  - Click on the **Details** button for the app that you just created
#  - Click on the **Keys & Tokens** tab:
#    - Two keys should already be given to you:  **API Key** & **API Secret Key**
#    - Two you have to generate:  **Access token** & **Access token secret**
#  - Generate your Access Token and Access Token Secret keys.  You'll need to write these down when you're done -- you can only see them once.
#
# Now you're ready to make requests to the Twitter api.  Everytime you make a request, you'll need to include the 4 tokens you just created.  (You can always regenerate them for whatever reason).

# %% [markdown]
# **Step 4:  Your First Request**
#
# To make requests to the Twitter API you're going to need a module which is **not** already pre-installed in Anaconda. You'll need to install it via PIP, which is python's package manager.  It's called `requests_oauthlib`.  You can install this via Anaconda Prompt or Terminal by simply typing in the command `pip install requests_oauthlib`, and then you'll be finished.
#
# The logistics of making an OAuth1 authenticated request are very similar to what was done in class 3, but with a few additional steps.  You can see how to do it here:  https://requests.readthedocs.io/en/master/user/authentication/#oauth-1-authentication.  The only thing you'll need to change is the info for your API tokens that are passed into the `OAuth1()` function.
#
# Try making a request to the following URL to confirm that you have things set up correctly: 'https://api.twitter.com/1.1/account/verify_credentials.json'

# %%
# your code here
import requests
from requests_oauthlib import OAuth1

url = 'https://api.twitter.com/1.1/account/verify_credentials.json'
auth = OAuth1()

requests.get(url, auth=auth).json()
# Out:
# {'id': 1291416908072353793,
#  'id_str': '1291416908072353793',
#  'name': 'Neraj Thangarajah',
#  'screen_name': 'NerajThangaraj1',
#  'location': '',
#  'description': '',
#  'url': None,
#  'entities': {'description': {'urls': []}},
#  'protected': False,
#  'followers_count': 0,
#  'friends_count': 0,
#  'listed_count': 0,
#  'created_at': 'Thu Aug 06 16:52:50 +0000 2020',
#  'favourites_count': 0,
#  'utc_offset': None,
#  'time_zone': None,
#  'geo_enabled': False,
#  'verified': False,
#  'statuses_count': 0,
#  'lang': None,
#  'contributors_enabled': False,
#  'is_translator': False,
#  'is_translation_enabled': False,
#  'profile_background_color': 'F5F8FA',
#  'profile_background_image_url': None,
#  'profile_background_image_url_https': None,
#  'profile_background_tile': False,
#  'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#  'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#  'profile_link_color': '1DA1F2',
#  'profile_sidebar_border_color': 'C0DEED',
#  'profile_sidebar_fill_color': 'DDEEF6',
#  'profile_text_color': '333333',
#  'profile_use_background_image': True,
#  'has_extended_profile': True,
#  'default_profile': True,
#  'default_profile_image': True,
#  'following': False,
#  'follow_request_sent': False,
#  'notifications': False,
#  'translator_type': 'none',
#  'suspended': False,
#  'needs_phone_verification': False}

# %% [markdown]
# If you get your json object back, then you're good to go.

# %% [markdown]
# ## Section 2: Searching Tweets

# %% [markdown]
# Most websites you access will have a long string attached to the end of them that look something like this:  `http://thewebsite.com/?year=2019&color=golden%20yellow&user_id=48549395959438`.
#
# Most people have no reason to pay attention to any of this, but all the special symbols at the end are basically encoded commands that say 'return a website that displays x,y,z characteristics.'
#
# When accessing api data, it basically works the same way.

# %% [markdown]
# **Step 1:  Set Up Your First Query String**

# %% [markdown]
# If you go into Twitter and search for the term `Data Science`, you should be brought to a url that looks like this:  `https://twitter.com/search?q=Data%20Science&src=typed_query`
#
# If you'd like, you can drop the `&src=typed_query` from the url and still get the same results.
#
# There are some important details to pay attention to:
#
#  - Like class 3 when we worked with GitHub, there is a **base url**.  In this case it's `https://twitter.com/search`
#  - Whenever you enter a search for something, the base url will be followed by something that looks like `?q=My%20Search%20Term`
#   - The `?` marks the beginning of the query string.  This basically says 'initiate a request with whatever parameters that follow'
#   - The `q` is a **parameter**, essentially some condition to pass into the query string that determines what results will be given back to you.  In this case, `q` encodes the text you typed in into something the API can understand.
#
# **Useful Thing To Do Right Now:** Go back to the Twitter search page, and just try searching for different things, and notice what shows up after the `q=`.  Here are some questions to ask yourself:
#
#  - How are white spaces encoded?  Ie, if you search for `Jonathan Bechtel` in the search box, what shows up to account for the space between the two words?
#  - What about hash symbols?  If you search for `#MeToo`, `#GirlsWhoCode` or `#DataScience`, what happens with that `#` symbol?
#  - Once you get the hang of this, see if you can just re-create some searches yourself by creating the url directly, and bypassing the search box altogether.  Ie, be familiar enough with how searches are formatted that you know `https://twitter.com/search?q=%23DataScience` will take you to the same page as typing in `#DataScience` into the search box.
#
# Now, let's try and make a request for a search for `Data Science`.
#
# If you look at Twitter's docs, you'll see that the base url for the search API is `'https://api.twitter.com/1.1/search/tweets.json`
#
# This means you have to add the `?q=Whatever%20Word%20%Goes%20Here` to the end to complete the search.
#
# So go ahead, and see if you can create your API call for a search for the term `Data Science`.
#
# If you did it correctly, you should have a dictionary with a key called `statuses`, and it'll be a list with all of the tweets returned by your search.

# %%
# # is represented by %23 in search string, spaces look like white space but are probably underscores?
base_url = 'https://api.twitter.com/1.1/search/tweets.json'
search = '?q=datascience'

search_results = requests.get(base_url + search, auth=auth).json()
search_results
# Out:
# {'statuses': [{'created_at': 'Sat Aug 08 11:39:01 +0000 2020',
#    'id': 1292062757135749130,
#    'id_str': '1292062757135749130',
#    'text': 'RT @gp_pulipaka: Top Best #Python #Books of All Time Review 2020. #BigData #Analytics #DataScience #IoT #IIoT #PyTorch #Python #RStats #Ten…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'Python', 'indices': [26, 33]},
#      {'text': 'Books', 'indices': [34, 40]},
#      {'text': 'BigData', 'indices': [66, 74]},
#      {'text': 'Analytics', 'indices': [75, 85]},
#      {'text': 'DataScience', 'indices': [86, 98]},
#      {'text': 'IoT', 'indices': [99, 103]},
#      {'text': 'IIoT', 'indices': [104, 109]},
#      {'text': 'PyTorch', 'indices': [110, 118]},
#      {'text': 'Python', 'indices': [119, 126]},
#      {'text': 'RStats', 'indices': [127, 134]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'gp_pulipaka',
#       'name': 'Dr. Ganapathi Pulipaka',
#       'id': 4263007693,
#       'id_str': '4263007693',
#       'indices': [3, 15]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://localhost.com" rel="nofollow">Explore Twitter Api</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 3197518417,
#     'id_str': '3197518417',
#     'name': "Amy O'Neill",
#     'screen_name': 'AmyOh89',
#     'location': 'Austin, TX',
#     'description': 'I love programming and technology.  Currently on a project using #Angular, @IonicFramework, Cordova, MongoDB, and Node.js.  I also love my dog, Henry.',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 9647,
#     'friends_count': 7537,
#     'listed_count': 800,
#     'created_at': 'Sat May 16 13:38:42 +0000 2015',
#     'favourites_count': 5956,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 11927,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/600806794005360641/r-NGHq-j_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/600806794005360641/r-NGHq-j_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3197518417/1431784641',
#     'profile_link_color': '19CF86',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sat Aug 08 06:07:17 +0000 2020',
#     'id': 1291979275676131328,
#     'id_str': '1291979275676131328',
#     'text': 'Top Best #Python #Books of All Time Review 2020. #BigData #Analytics #DataScience #IoT #IIoT #PyTorch #Python… https://t.co/E4MN51SQew',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'Python', 'indices': [9, 16]},
#       {'text': 'Books', 'indices': [17, 23]},
#       {'text': 'BigData', 'indices': [49, 57]},
#       {'text': 'Analytics', 'indices': [58, 68]},
#       {'text': 'DataScience', 'indices': [69, 81]},
#       {'text': 'IoT', 'indices': [82, 86]},
#       {'text': 'IIoT', 'indices': [87, 92]},
#       {'text': 'PyTorch', 'indices': [93, 101]},
#       {'text': 'Python', 'indices': [102, 109]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/E4MN51SQew',
#        'expanded_url': 'https://twitter.com/i/web/status/1291979275676131328',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [111, 134]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://buffer.com" rel="nofollow">Buffer</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 4263007693,
#      'id_str': '4263007693',
#      'name': 'Dr. Ganapathi Pulipaka',
#      'screen_name': 'gp_pulipaka',
#      'location': 'Redondo Beach, CA',
#      'description': 'Chief AI HPC Scientist | Global Premier Speaker | PostDoc CS, PhD | Bestselling Author | 18.4M Views Per Month | Top Data Science, IIoT Influencer @Onalytica',
#      'url': 'https://t.co/eYyaJsEcfw',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/eYyaJsEcfw',
#          'expanded_url': 'http://www.gppulipaka.org',
#          'display_url': 'gppulipaka.org',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 94403,
#      'friends_count': 26859,
#      'listed_count': 3438,
#      'created_at': 'Tue Nov 17 02:19:09 +0000 2015',
#      'favourites_count': 9,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 57239,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/998301258413850625/9BZwTjgv_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/998301258413850625/9BZwTjgv_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/4263007693/1583526136',
#      'profile_link_color': 'DD2E44',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 65,
#     'favorite_count': 68,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 65,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Sat Aug 08 11:38:22 +0000 2020',
#    'id': 1292062595244085252,
#    'id_str': '1292062595244085252',
#    'text': 'RT @IAM__Network: Worldwide Delivery Management Software Industry to 2027 – Big Data Analytics Technology to Improve Delivery Operations…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'IAM__Network',
#       'name': 'IAM Platform',
#       'id': 226310002,
#       'id_str': '226310002',
#       'indices': [3, 16]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 781961216,
#     'id_str': '781961216',
#     'name': 'Giovanni Greatti',
#     'screen_name': 'GioGreatti',
#     'location': 'Monticello Brianza, Lombardia',
#     'description': 'Senior PCB Designer, R&D Engineer and AI-ML Certified Scientist🇪🇺🇮🇹♊️♍️',
#     'url': 'https://t.co/MUdMOdbmOX',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/MUdMOdbmOX',
#         'expanded_url': 'http://www.widelab.net',
#         'display_url': 'widelab.net',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1355,
#     'friends_count': 4593,
#     'listed_count': 20,
#     'created_at': 'Sun Aug 26 07:51:50 +0000 2012',
#     'favourites_count': 28838,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 31034,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '2D4F8A',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme10/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme10/bg.gif',
#     'profile_background_tile': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1277019333680644097/qgBWvkG1_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1277019333680644097/qgBWvkG1_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/781961216/1399137145',
#     'profile_link_color': '1B95E0',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sat Aug 08 11:32:14 +0000 2020',
#     'id': 1292061051664596992,
#     'id_str': '1292061051664596992',
#     'text': 'Worldwide Delivery Management Software Industry to 2027 – Big Data Analytics Technology to Improve Delivery Operati… https://t.co/QeidlFI4c5',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/QeidlFI4c5',
#        'expanded_url': 'https://twitter.com/i/web/status/1292061051664596992',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://www.blog.iammarketingmedia.com" rel="nofollow">IAMBLOG2TWITTER</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 226310002,
#      'id_str': '226310002',
#      'name': 'IAM Platform',
#      'screen_name': 'IAM__Network',
#      'location': 'Worldwide',
#      'description': 'Curation | Tools | Tips | Services\n\nIAM Platform powers IAM Network:\n\nGO: https://t.co/OJVc7LULBT\n\nBlog | Social | Podcast | Code Trove',
#      'url': 'https://t.co/T1FCdoOFoB',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/T1FCdoOFoB',
#          'expanded_url': 'https://www.iammarketingmedia.com',
#          'display_url': 'iammarketingmedia.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': [{'url': 'https://t.co/OJVc7LULBT',
#          'expanded_url': 'http://bit.ly/2Ywsbg8',
#          'display_url': 'bit.ly/2Ywsbg8',
#          'indices': [74, 97]}]}},
#      'protected': False,
#      'followers_count': 17968,
#      'friends_count': 15093,
#      'listed_count': 3290,
#      'created_at': 'Mon Dec 13 21:24:29 +0000 2010',
#      'favourites_count': 65473,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 765046,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '94D487',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/701708113653669888/Nzm67hhC_normal.png',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/701708113653669888/Nzm67hhC_normal.png',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/226310002/1584072260',
#      'profile_link_color': '3366CC',
#      'profile_sidebar_border_color': 'FFFFFF',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 2,
#     'favorite_count': 2,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 2,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Sat Aug 08 11:38:14 +0000 2020',
#    'id': 1292062560154456064,
#    'id_str': '1292062560154456064',
#    'text': 'RT @FalseSenseOfSec: Deaths From COVID-19 Rapidly Rise Again in the U.S. #COVID19 #dataviz #AWS #dataanalytics #azure #MachineLearning #Dee…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'COVID19', 'indices': [73, 81]},
#      {'text': 'dataviz', 'indices': [82, 90]},
#      {'text': 'AWS', 'indices': [91, 95]},
#      {'text': 'dataanalytics', 'indices': [96, 110]},
#      {'text': 'azure', 'indices': [111, 117]},
#      {'text': 'MachineLearning', 'indices': [118, 134]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'FalseSenseOfSec',
#       'name': 'False Sense Of Security',
#       'id': 937089392262332417,
#       'id_str': '937089392262332417',
#       'indices': [3, 19]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://google.com" rel="nofollow">@erRaghavKhanna</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1182866592138350592,
#     'id_str': '1182866592138350592',
#     'name': 'Inferno',
#     'screen_name': 'theInfernobot',
#     'location': '',
#     'description': "Hi! I am a bot made by @erRaghavkhanna I'm programmed to retweet, like & reply #30daysofkotlin #100daysofcode #JavaScript. Please support me by following me😍",
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 804,
#     'friends_count': 1,
#     'listed_count': 31,
#     'created_at': 'Sat Oct 12 03:52:42 +0000 2019',
#     'favourites_count': 5461,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 157622,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1263711283196633089/mckc1xGI_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1263711283196633089/mckc1xGI_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1182866592138350592/1590398965',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sat Aug 08 11:37:03 +0000 2020',
#     'id': 1292062262241439750,
#     'id_str': '1292062262241439750',
#     'text': 'Deaths From COVID-19 Rapidly Rise Again in the U.S. #COVID19 #dataviz #AWS #dataanalytics #azure #MachineLearning… https://t.co/CHx5bbyFZH',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'COVID19', 'indices': [52, 60]},
#       {'text': 'dataviz', 'indices': [61, 69]},
#       {'text': 'AWS', 'indices': [70, 74]},
#       {'text': 'dataanalytics', 'indices': [75, 89]},
#       {'text': 'azure', 'indices': [90, 96]},
#       {'text': 'MachineLearning', 'indices': [97, 113]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/CHx5bbyFZH',
#        'expanded_url': 'https://twitter.com/i/web/status/1292062262241439750',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [115, 138]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 937089392262332417,
#      'id_str': '937089392262332417',
#      'name': 'False Sense Of Security',
#      'screen_name': 'FalseSenseOfSec',
#      'location': '',
#      'description': 'Data Science l DevSecOps l Network Automation https://t.co/lIiXrloI5S',
#      'url': None,
#      'entities': {'description': {'urls': [{'url': 'https://t.co/lIiXrloI5S',
#          'expanded_url': 'https://www.youtube.com/channel/UCADaZ4X2-wBZf1kXDQsFmGA',
#          'display_url': 'youtube.com/channel/UCADaZ…',
#          'indices': [46, 69]}]}},
#      'protected': False,
#      'followers_count': 994,
#      'friends_count': 97,
#      'listed_count': 1,
#      'created_at': 'Sat Dec 02 22:41:36 +0000 2017',
#      'favourites_count': 722,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 1137,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/944583077996711940/rw3VjpKY_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/944583077996711940/rw3VjpKY_normal.jpg',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 10,
#     'favorite_count': 1,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 10,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Sat Aug 08 11:37:50 +0000 2020',
#    'id': 1292062460778708993,
#    'id_str': '1292062460778708993',
#    'text': 'RT @RichardEudes: How to Use XGBoost for Time Series Forecasting https://t.co/i2ABE1wk5K #analytics #datascience, #bigdata, #datascience, #…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'analytics', 'indices': [89, 99]},
#      {'text': 'datascience', 'indices': [100, 112]},
#      {'text': 'bigdata', 'indices': [114, 122]},
#      {'text': 'datascience', 'indices': [124, 136]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'RichardEudes',
#       'name': 'Richard Eudes, PhD',
#       'id': 49427323,
#       'id_str': '49427323',
#       'indices': [3, 16]}],
#     'urls': [{'url': 'https://t.co/i2ABE1wk5K',
#       'expanded_url': 'https://bit.ly/2DAF7ZY',
#       'display_url': 'bit.ly/2DAF7ZY',
#       'indices': [65, 88]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 766796667957891076,
#     'id_str': '766796667957891076',
#     'name': 'Maignanamoorthy',
#     'screen_name': 'Maignanamurthy',
#     'location': 'Gobichettipalayam',
#     'description': 'In search of an environment to live',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 123,
#     'friends_count': 623,
#     'listed_count': 4,
#     'created_at': 'Sat Aug 20 00:39:06 +0000 2016',
#     'favourites_count': 2458,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 8291,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/813589438420774912/x4EnCPvU_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/813589438420774912/x4EnCPvU_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/766796667957891076/1507884892',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sat Aug 08 11:29:01 +0000 2020',
#     'id': 1292060240347897856,
#     'id_str': '1292060240347897856',
#     'text': 'How to Use XGBoost for Time Series Forecasting https://t.co/i2ABE1wk5K #analytics #datascience, #bigdata,… https://t.co/1swGkDL8Nq',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'analytics', 'indices': [71, 81]},
#       {'text': 'datascience', 'indices': [82, 94]},
#       {'text': 'bigdata', 'indices': [96, 104]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/i2ABE1wk5K',
#        'expanded_url': 'https://bit.ly/2DAF7ZY',
#        'display_url': 'bit.ly/2DAF7ZY',
#        'indices': [47, 70]},
#       {'url': 'https://t.co/1swGkDL8Nq',
#        'expanded_url': 'https://twitter.com/i/web/status/1292060240347897856',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [107, 130]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://buffer.com" rel="nofollow">Buffer</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 49427323,
#      'id_str': '49427323',
#      'name': 'Richard Eudes, PhD',
#      'screen_name': 'RichardEudes',
#      'location': 'Paris, France',
#      'description': 'Chief Data Scientist - Head of #BigData & #AdvancedAnalytics -#Analytics #DataScience #MachineLearning #ArtificialIntelligence',
#      'url': 'https://t.co/SbKL2gaZoe',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/SbKL2gaZoe',
#          'expanded_url': 'http://www.datascientists.fr',
#          'display_url': 'datascientists.fr',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 15797,
#      'friends_count': 2152,
#      'listed_count': 646,
#      'created_at': 'Sun Jun 21 21:04:32 +0000 2009',
#      'favourites_count': 1042,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 28756,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme15/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme15/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1023964224656171008/JH0y7fV2_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1023964224656171008/JH0y7fV2_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/49427323/1591550810',
#      'profile_link_color': '0050A0',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 2,
#     'favorite_count': 1,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 2,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Sat Aug 08 11:37:38 +0000 2020',
#    'id': 1292062410472337408,
#    'id_str': '1292062410472337408',
#    'text': 'RT @FalseSenseOfSec: Deaths From COVID-19 Rapidly Rise Again in the U.S. #COVID19 #dataviz #AWS #dataanalytics #azure #MachineLearning #Dee…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'COVID19', 'indices': [73, 81]},
#      {'text': 'dataviz', 'indices': [82, 90]},
#      {'text': 'AWS', 'indices': [91, 95]},
#      {'text': 'dataanalytics', 'indices': [96, 110]},
#      {'text': 'azure', 'indices': [111, 117]},
#      {'text': 'MachineLearning', 'indices': [118, 134]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'FalseSenseOfSec',
#       'name': 'False Sense Of Security',
#       'id': 937089392262332417,
#       'id_str': '937089392262332417',
#       'indices': [3, 19]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://nlogn.in" rel="nofollow">nlognrobot</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1260062769543434240,
#     'id_str': '1260062769543434240',
#     'name': '#100DaysOfCode',
#     'screen_name': 'nlognbot',
#     'location': '',
#     'description': "Hi, I'm a bot that retweets #100daysofcode #javascript and #nlogn\nYou can follow me.😉\n\nP.S. I was created by @nlognco DM for removal of offensive content.",
#     'url': 'https://t.co/PujHDQomPA',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/PujHDQomPA',
#         'expanded_url': 'http://nlogn.in',
#         'display_url': 'nlogn.in',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1504,
#     'friends_count': 2,
#     'listed_count': 41,
#     'created_at': 'Tue May 12 04:22:53 +0000 2020',
#     'favourites_count': 285,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 197379,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1279361917522284544/7wvRIVrE_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1279361917522284544/7wvRIVrE_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1260062769543434240/1593858684',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sat Aug 08 11:37:03 +0000 2020',
#     'id': 1292062262241439750,
#     'id_str': '1292062262241439750',
#     'text': 'Deaths From COVID-19 Rapidly Rise Again in the U.S. #COVID19 #dataviz #AWS #dataanalytics #azure #MachineLearning… https://t.co/CHx5bbyFZH',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'COVID19', 'indices': [52, 60]},
#       {'text': 'dataviz', 'indices': [61, 69]},
#       {'text': 'AWS', 'indices': [70, 74]},
#       {'text': 'dataanalytics', 'indices': [75, 89]},
#       {'text': 'azure', 'indices': [90, 96]},
#       {'text': 'MachineLearning', 'indices': [97, 113]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/CHx5bbyFZH',
#        'expanded_url': 'https://twitter.com/i/web/status/1292062262241439750',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [115, 138]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 937089392262332417,
#      'id_str': '937089392262332417',
#      'name': 'False Sense Of Security',
#      'screen_name': 'FalseSenseOfSec',
#      'location': '',
#      'description': 'Data Science l DevSecOps l Network Automation https://t.co/lIiXrloI5S',
#      'url': None,
#      'entities': {'description': {'urls': [{'url': 'https://t.co/lIiXrloI5S',
#          'expanded_url': 'https://www.youtube.com/channel/UCADaZ4X2-wBZf1kXDQsFmGA',
#          'display_url': 'youtube.com/channel/UCADaZ…',
#          'indices': [46, 69]}]}},
#      'protected': False,
#      'followers_count': 994,
#      'friends_count': 97,
#      'listed_count': 1,
#      'created_at': 'Sat Dec 02 22:41:36 +0000 2017',
#      'favourites_count': 722,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 1137,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/944583077996711940/rw3VjpKY_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/944583077996711940/rw3VjpKY_normal.jpg',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 10,
#     'favorite_count': 1,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 10,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Sat Aug 08 11:37:30 +0000 2020',
#    'id': 1292062377127673856,
#    'id_str': '1292062377127673856',
#    'text': 'RT @FalseSenseOfSec: Deaths From COVID-19 Rapidly Rise Again in the U.S. #COVID19 #dataviz #AWS #dataanalytics #azure #MachineLearning #Dee…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'COVID19', 'indices': [73, 81]},
#      {'text': 'dataviz', 'indices': [82, 90]},
#      {'text': 'AWS', 'indices': [91, 95]},
#      {'text': 'dataanalytics', 'indices': [96, 110]},
#      {'text': 'azure', 'indices': [111, 117]},
#      {'text': 'MachineLearning', 'indices': [118, 134]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'FalseSenseOfSec',
#       'name': 'False Sense Of Security',
#       'id': 937089392262332417,
#       'id_str': '937089392262332417',
#       'indices': [3, 19]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://rahedmir.github.io" rel="nofollow">Coding NinjaBOT</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1229842670710902785,
#     'id_str': '1229842670710902785',
#     'name': 'Coding NinjaBOT 🤖',
#     'screen_name': 'CodingNinjaBOT',
#     'location': 'Coding World!',
#     'description': 'Retweets 📃 #coding related stuff :)  (retweets once per hour on a random basis.)',
#     'url': 'https://t.co/WmhSLVGxW2',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/WmhSLVGxW2',
#         'expanded_url': 'https://rahedmir.github.io/',
#         'display_url': 'rahedmir.github.io',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 320,
#     'friends_count': 3,
#     'listed_count': 17,
#     'created_at': 'Tue Feb 18 18:59:32 +0000 2020',
#     'favourites_count': 110,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 18136,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1229848030960115712/W3TebBgV_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1229848030960115712/W3TebBgV_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1229842670710902785/1582054823',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sat Aug 08 11:37:03 +0000 2020',
#     'id': 1292062262241439750,
#     'id_str': '1292062262241439750',
#     'text': 'Deaths From COVID-19 Rapidly Rise Again in the U.S. #COVID19 #dataviz #AWS #dataanalytics #azure #MachineLearning… https://t.co/CHx5bbyFZH',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'COVID19', 'indices': [52, 60]},
#       {'text': 'dataviz', 'indices': [61, 69]},
#       {'text': 'AWS', 'indices': [70, 74]},
#       {'text': 'dataanalytics', 'indices': [75, 89]},
#       {'text': 'azure', 'indices': [90, 96]},
#       {'text': 'MachineLearning', 'indices': [97, 113]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/CHx5bbyFZH',
#        'expanded_url': 'https://twitter.com/i/web/status/1292062262241439750',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [115, 138]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 937089392262332417,
#      'id_str': '937089392262332417',
#      'name': 'False Sense Of Security',
#      'screen_name': 'FalseSenseOfSec',
#      'location': '',
#      'description': 'Data Science l DevSecOps l Network Automation https://t.co/lIiXrloI5S',
#      'url': None,
#      'entities': {'description': {'urls': [{'url': 'https://t.co/lIiXrloI5S',
#          'expanded_url': 'https://www.youtube.com/channel/UCADaZ4X2-wBZf1kXDQsFmGA',
#          'display_url': 'youtube.com/channel/UCADaZ…',
#          'indices': [46, 69]}]}},
#      'protected': False,
#      'followers_count': 994,
#      'friends_count': 97,
#      'listed_count': 1,
#      'created_at': 'Sat Dec 02 22:41:36 +0000 2017',
#      'favourites_count': 722,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 1137,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/944583077996711940/rw3VjpKY_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/944583077996711940/rw3VjpKY_normal.jpg',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 10,
#     'favorite_count': 1,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 10,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Sat Aug 08 11:37:30 +0000 2020',
#    'id': 1292062374229401600,
#    'id_str': '1292062374229401600',
#    'text': 'RT @chidambara09: #Conversational #AI Comes of Age -  https://t.co/FCWQBABuT9  \n\nby\nsherry Comes\n\n#bigdata \n\n#USA🐦#canada #london #Australi…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'Conversational', 'indices': [18, 33]},
#      {'text': 'AI', 'indices': [34, 37]},
#      {'text': 'bigdata', 'indices': [98, 106]},
#      {'text': 'USA', 'indices': [109, 113]},
#      {'text': 'canada', 'indices': [114, 121]},
#      {'text': 'london', 'indices': [122, 129]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'chidambara09',
#       'name': 'Chidambara .ML.',
#       'id': 737142202481016832,
#       'id_str': '737142202481016832',
#       'indices': [3, 16]}],
#     'urls': [{'url': 'https://t.co/FCWQBABuT9',
#       'expanded_url': 'http://www.informationweek.com/big-data/ai-machine-learning/conversational-ai-comes-of-age/a/d-id/1338423',
#       'display_url': 'informationweek.com/big-data/ai-ma…',
#       'indices': [54, 77]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://go-shopal.herokuapp.com" rel="nofollow">RedianDevBot</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1229091405152256001,
#     'id_str': '1229091405152256001',
#     'name': 'Ready Dev',
#     'screen_name': 'redianbot',
#     'location': 'Albania',
#     'description': 'This is a BOT builded by @rediandev for Ready Dev YouTube Channel.\nPlease make sure to follow @rediandev and SUBSCRIBE ➡️ https://t.co/9ToeXMKBZR',
#     'url': 'https://t.co/9ToeXMKBZR',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/9ToeXMKBZR',
#         'expanded_url': 'https://bit.ly/35yvIvK',
#         'display_url': 'bit.ly/35yvIvK',
#         'indices': [0, 23]}]},
#      'description': {'urls': [{'url': 'https://t.co/9ToeXMKBZR',
#         'expanded_url': 'https://bit.ly/35yvIvK',
#         'display_url': 'bit.ly/35yvIvK',
#         'indices': [122, 145]}]}},
#     'protected': False,
#     'followers_count': 576,
#     'friends_count': 1,
#     'listed_count': 26,
#     'created_at': 'Sun Feb 16 17:14:48 +0000 2020',
#     'favourites_count': 39821,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 244144,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1257971099859480576/am4cu8pF_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1257971099859480576/am4cu8pF_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1229091405152256001/1588758663',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sat Aug 08 11:37:15 +0000 2020',
#     'id': 1292062313055260673,
#     'id_str': '1292062313055260673',
#     'text': '#Conversational #AI Comes of Age -  https://t.co/FCWQBABuT9  \n\nby\nsherry Comes\n\n#bigdata \n\n#USA🐦#canada #london… https://t.co/RVM5qUWvOY',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'Conversational', 'indices': [0, 15]},
#       {'text': 'AI', 'indices': [16, 19]},
#       {'text': 'bigdata', 'indices': [80, 88]},
#       {'text': 'USA', 'indices': [91, 95]},
#       {'text': 'canada', 'indices': [96, 103]},
#       {'text': 'london', 'indices': [104, 111]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/FCWQBABuT9',
#        'expanded_url': 'http://www.informationweek.com/big-data/ai-machine-learning/conversational-ai-comes-of-age/a/d-id/1338423',
#        'display_url': 'informationweek.com/big-data/ai-ma…',
#        'indices': [36, 59]},
#       {'url': 'https://t.co/RVM5qUWvOY',
#        'expanded_url': 'https://twitter.com/i/web/status/1292062313055260673',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [113, 136]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 737142202481016832,
#      'id_str': '737142202481016832',
#      'name': 'Chidambara .ML.',
#      'screen_name': 'chidambara09',
#      'location': 'Mysore  and  BERLIN',
#      'description': 'Be happy  Be healthy Be smile Be cool Be good human',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 7118,
#      'friends_count': 13,
#      'listed_count': 4427,
#      'created_at': 'Mon May 30 04:42:51 +0000 2016',
#      'favourites_count': 192,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 1098687,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/760774125522518016/jhzjWv0i_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/760774125522518016/jhzjWv0i_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/737142202481016832/1538216794',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 8,
#     'favorite_count': 2,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 8,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Sat Aug 08 11:37:28 +0000 2020',
#    'id': 1292062369351454721,
#    'id_str': '1292062369351454721',
#    'text': 'RT @Jaipur_Manipal: @Jaipur_Manipal (#MUJ) offers #MTech Programs with a #scholarship of Rs. 15,000/- per month to all #GATE qualified stud…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'MUJ', 'indices': [37, 41]},
#      {'text': 'MTech', 'indices': [50, 56]},
#      {'text': 'scholarship', 'indices': [73, 85]},
#      {'text': 'GATE', 'indices': [119, 124]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'Jaipur_Manipal',
#       'name': 'Manipal Jaipur',
#       'id': 4067804412,
#       'id_str': '4067804412',
#       'indices': [3, 18]},
#      {'screen_name': 'Jaipur_Manipal',
#       'name': 'Manipal Jaipur',
#       'id': 4067804412,
#       'id_str': '4067804412',
#       'indices': [20, 35]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '',
# ...
#      'friends_count': 13,
#      'listed_count': 4427,
#      'created_at': 'Mon May 30 04:42:51 +0000 2016',
#      'favourites_count': 192,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 1098687,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/760774125522518016/jhzjWv0i_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/760774125522518016/jhzjWv0i_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/737142202481016832/1538216794',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 8,
#     'favorite_count': 2,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 8,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Sat Aug 08 11:37:24 +0000 2020',
#    'id': 1292062350036676609,
#    'id_str': '1292062350036676609',
#    'text': 'RT @chidambara09: #Conversational #AI Comes of Age -  https://t.co/FCWQBABuT9  \n\nby\nsherry Comes\n\n#bigdata \n\n#USA🐦#canada #london #Australi…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'Conversational', 'indices': [18, 33]},
#      {'text': 'AI', 'indices': [34, 37]},
#      {'text': 'bigdata', 'indices': [98, 106]},
#      {'text': 'USA', 'indices': [109, 113]},
#      {'text': 'canada', 'indices': [114, 121]},
#      {'text': 'london', 'indices': [122, 129]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'chidambara09',
#       'name': 'Chidambara .ML.',
#       'id': 737142202481016832,
#       'id_str': '737142202481016832',
#       'indices': [3, 16]}],
#     'urls': [{'url': 'https://t.co/FCWQBABuT9',
#       'expanded_url': 'http://www.informationweek.com/big-data/ai-machine-learning/conversational-ai-comes-of-age/a/d-id/1338423',
#       'display_url': 'informationweek.com/big-data/ai-ma…',
#       'indices': [54, 77]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://google.com" rel="nofollow">@erRaghavKhanna</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1182866592138350592,
#     'id_str': '1182866592138350592',
#     'name': 'Inferno',
#     'screen_name': 'theInfernobot',
#     'location': '',
#     'description': "Hi! I am a bot made by @erRaghavkhanna I'm programmed to retweet, like & reply #30daysofkotlin #100daysofcode #JavaScript. Please support me by following me😍",
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 804,
#     'friends_count': 1,
#     'listed_count': 31,
#     'created_at': 'Sat Oct 12 03:52:42 +0000 2019',
#     'favourites_count': 5461,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 157622,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1263711283196633089/mckc1xGI_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1263711283196633089/mckc1xGI_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1182866592138350592/1590398965',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sat Aug 08 11:37:15 +0000 2020',
#     'id': 1292062313055260673,
#     'id_str': '1292062313055260673',
#     'text': '#Conversational #AI Comes of Age -  https://t.co/FCWQBABuT9  \n\nby\nsherry Comes\n\n#bigdata \n\n#USA🐦#canada #london… https://t.co/RVM5qUWvOY',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'Conversational', 'indices': [0, 15]},
#       {'text': 'AI', 'indices': [16, 19]},
#       {'text': 'bigdata', 'indices': [80, 88]},
#       {'text': 'USA', 'indices': [91, 95]},
#       {'text': 'canada', 'indices': [96, 103]},
#       {'text': 'london', 'indices': [104, 111]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/FCWQBABuT9',
#        'expanded_url': 'http://www.informationweek.com/big-data/ai-machine-learning/conversational-ai-comes-of-age/a/d-id/1338423',
#        'display_url': 'informationweek.com/big-data/ai-ma…',
#        'indices': [36, 59]},
#       {'url': 'https://t.co/RVM5qUWvOY',
#        'expanded_url': 'https://twitter.com/i/web/status/1292062313055260673',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [113, 136]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 737142202481016832,
#      'id_str': '737142202481016832',
#      'name': 'Chidambara .ML.',
#      'screen_name': 'chidambara09',
#      'location': 'Mysore  and  BERLIN',
#      'description': 'Be happy  Be healthy Be smile Be cool Be good human',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 7118,
#      'friends_count': 13,
#      'listed_count': 4427,
#      'created_at': 'Mon May 30 04:42:51 +0000 2016',
#      'favourites_count': 192,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 1098687,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/760774125522518016/jhzjWv0i_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/760774125522518016/jhzjWv0i_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/737142202481016832/1538216794',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 8,
#     'favorite_count': 2,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 8,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Sat Aug 08 11:37:23 +0000 2020',
#    'id': 1292062347536797696,
#    'id_str': '1292062347536797696',
#    'text': 'RT @ProgrammerBooks: Augmented Reality for Android Application ... ==&gt; https://t.co/LE3q3MRE37\n\n#python #javascript #angular #reactjs #vuej…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'python', 'indices': [99, 106]},
#      {'text': 'javascript', 'indices': [107, 118]},
#      {'text': 'angular', 'indices': [119, 127]},
#      {'text': 'reactjs', 'indices': [128, 136]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'ProgrammerBooks',
#       'name': 'Programmer Books',
#       'id': 992142356420980738,
#       'id_str': '992142356420980738',
#       'indices': [3, 19]}],
#     'urls': [{'url': 'https://t.co/LE3q3MRE37',
#       'expanded_url': 'https://www.programmer-books.com/augmented-reality-for-android-application-development/',
#       'display_url': 'programmer-books.com/augmented-real…',
#       'indices': [74, 97]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://addempsea.wordpress.com" rel="nofollow">Twitter for addempsea</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1196874000837816320,
#     'id_str': '1196874000837816320',
#     'name': 'quotesBot',
#     'screen_name': 'nodeQuotesBot',
#     'location': '',
#     'description': 'I am a bot made by @_addempsea  with #nodejs. I post quotes every hour and I retweet #js #javascript and #rustlang post. Kindly follow me',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 975,
#     'friends_count': 1,
#     'listed_count': 33,
#     'created_at': 'Tue Nov 19 19:33:16 +0000 2019',
#     'favourites_count': 0,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 147131,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1272605555497078785/WLzdWQ-o_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1272605555497078785/WLzdWQ-o_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1196874000837816320/1577825239',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sat Aug 08 04:59:10 +0000 2020',
#     'id': 1291962132972670976,
#     'id_str': '1291962132972670976',
#     'text': 'Augmented Reality for Android Application ... ==&gt; https://t.co/LE3q3MRE37\n\n#python #javascript #angular #reactjs… https://t.co/kA1Sh8YKT7',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'python', 'indices': [78, 85]},
#       {'text': 'javascript', 'indices': [86, 97]},
#       {'text': 'angular', 'indices': [98, 106]},
#       {'text': 'reactjs', 'indices': [107, 115]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/LE3q3MRE37',
#        'expanded_url': 'https://www.programmer-books.com/augmented-reality-for-android-application-development/',
#        'display_url': 'programmer-books.com/augmented-real…',
#        'indices': [53, 76]},
#       {'url': 'https://t.co/kA1Sh8YKT7',
#        'expanded_url': 'https://twitter.com/i/web/status/1291962132972670976',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://programmer-books.com" rel="nofollow">ProgBooks</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 992142356420980738,
#      'id_str': '992142356420980738',
#      'name': 'Programmer Books',
#      'screen_name': 'ProgrammerBooks',
#      'location': 'Wordwide',
#      'description': 'Programmer-books is a great source of knowledge for software developers.  Here we share with you the best software development books to read.',
#      'url': 'https://t.co/mV6b2cwDsW',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/mV6b2cwDsW',
#          'expanded_url': 'https://programmer-books.com',
#          'display_url': 'programmer-books.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 3970,
#      'friends_count': 208,
#      'listed_count': 56,
#      'created_at': 'Thu May 03 20:42:25 +0000 2018',
#      'favourites_count': 437,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 11520,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1000551981331746818/GyBjfX2V_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1000551981331746818/GyBjfX2V_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/992142356420980738/1527047384',
#      'profile_link_color': '981CEB',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 20,
#     'favorite_count': 10,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 20,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'}],
#  'search_metadata': {'completed_in': 0.071,
#   'max_id': 1292062757135749130,
#   'max_id_str': '1292062757135749130',
#   'next_results': '?max_id=1292062347536797695&q=datascience&include_entities=1',
#   'query': 'datascience',
#   'refresh_url': '?since_id=1292062757135749130&q=datascience&include_entities=1',
#   'count': 15,
#   'since_id': 0,
#   'since_id_str': '0'}}

# %% [markdown]
# For good measure, try doing a search for tweets relating to `#MeToo` as well.

# %%
# your answer here
search = '?q=%23MeToo'

search_results = requests.get(base_url + search, auth=auth).json()
search_results
# Out:
# {'statuses': [{'created_at': 'Sat Aug 08 11:39:22 +0000 2020',
#    'id': 1292062846415589377,
#    'id_str': '1292062846415589377',
#    'text': '@DrkMeyyUQ9DmvlK #metoo',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'metoo', 'indices': [17, 23]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'DrkMeyyUQ9DmvlK',
#       'name': '石橋 茂🇯🇵',
#       'id': 1289883318670876672,
#       'id_str': '1289883318670876672',
#       'indices': [0, 16]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'und', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': 1292059371074027520,
#    'in_reply_to_status_id_str': '1292059371074027520',
#    'in_reply_to_user_id': 1289883318670876672,
#    'in_reply_to_user_id_str': '1289883318670876672',
#    'in_reply_to_screen_name': 'DrkMeyyUQ9DmvlK',
#    'user': {'id': 1204304246541148161,
#     'id_str': '1204304246541148161',
#     'name': '鶏キモ煮',
#     'screen_name': 'masao_torikimo2',
#     'location': '',
#     'description': '立憲民主党のカミツキガメ蓮舫にブロックされました✌これで晴れてネトウヨの仲間入りですね（笑）',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 64,
#     'friends_count': 130,
#     'listed_count': 2,
#     'created_at': 'Tue Dec 10 07:38:11 +0000 2019',
#     'favourites_count': 3303,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 1906,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1249605337126039552/KkAjftFz_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1249605337126039552/KkAjftFz_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1204304246541148161/1590322393',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'und'},
#   {'created_at': 'Sat Aug 08 11:38:19 +0000 2020',
#    'id': 1292062580345896960,
#    'id_str': '1292062580345896960',
#    'text': "La onda expansiva del movimiento #MeToo \n'Esto es placer' es, sí, uno de esos «libros que a nadie dejará indiferent… https://t.co/qzYUvutcPs",
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'MeToo', 'indices': [33, 39]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/qzYUvutcPs',
#       'expanded_url': 'https://twitter.com/i/web/status/1292062580345896960',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 173301796,
#     'id_str': '173301796',
#     'name': 'Consuelo Sáizar',
#     'screen_name': 'CSaizar',
#     'location': 'Cambridge, UK | México',
#     'description': 'Mexicana | Nayarita | Comunicación @Ibero_Mx | PhD Sociology Candidate @Cambridge_Uni | exPresidenta Conaculta | exDirectora @FCEMexico',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 61939,
#     'friends_count': 1111,
#     'listed_count': 659,
#     'created_at': 'Sun Aug 01 01:32:47 +0000 2010',
#     'favourites_count': 19207,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 65195,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '176691',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1267774774777982977/g2aMITw7_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1267774774777982977/g2aMITw7_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/173301796/1518320090',
#     'profile_link_color': '1B95E0',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': False,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 1,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'es'},
#   {'created_at': 'Sat Aug 08 11:38:01 +0000 2020',
#    'id': 1292062506991734784,
#    'id_str': '1292062506991734784',
#    'text': 'I think I remained life-positive, sex-positive, &amp; culture-positive thru it all\n\n#metoo #CSA #CSAsurvivor',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'metoo', 'indices': [84, 90]},
#      {'text': 'CSA', 'indices': [91, 95]},
#      {'text': 'CSAsurvivor', 'indices': [96, 108]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1031386774101258240,
#     'id_str': '1031386774101258240',
#     'name': 'Wolfgang',
#     'screen_name': 'Wolfg46611072',
#     'location': 'Newcastle upon Tyne, UK',
#     'description': 'migrant; writer non-fiction for $; #MeToo #CSA #DID-past "Every human being has the right to walk through this life with their full humanity intact" (Burke)',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 2637,
#     'friends_count': 3615,
#     'listed_count': 7,
#     'created_at': 'Mon Aug 20 03:45:43 +0000 2018',
#     'favourites_count': 4906,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 6630,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1196584489268469760/wLCNg_Z3_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1196584489268469760/wLCNg_Z3_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1031386774101258240/1591152505',
#     'profile_link_color': '981CEB',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Sat Aug 08 11:37:21 +0000 2020',
#    'id': 1292062339831943169,
#    'id_str': '1292062339831943169',
#    'text': 'RT @educate_tv: Bombshell: Another Drag Queen Story Hour Member Exposed as #LGBTPedophile, Report Says – NewsWars #Houston #pedophile #meto…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'LGBTPedophile', 'indices': [75, 89]},
#      {'text': 'Houston', 'indices': [114, 122]},
#      {'text': 'pedophile', 'indices': [123, 133]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'educate_tv',
#       'name': 'Educate-TV',
#       'id': 736556074564767744,
#       'id_str': '736556074564767744',
#       'indices': [3, 14]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1411487311,
#     'id_str': '1411487311',
#     'name': 'Cesia Paola Castro',
#     'screen_name': 'castrocesia',
#     'location': 'La Plata - Bs As',
#     'description': 'Hija, hermana y esposa. Estudiante Lengua Inglesa UNLP.',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 382,
#     'friends_count': 1523,
#     'listed_count': 0,
#     'created_at': 'Tue May 07 23:07:15 +0000 2013',
#     'favourites_count': 3426,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 7813,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1053835198511677441/mxOGixVV_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1053835198511677441/mxOGixVV_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1411487311/1540202036',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Fri Apr 05 15:52:04 +0000 2019',
#     'id': 1114193997038276610,
#     'id_str': '1114193997038276610',
#     'text': 'Bombshell: Another Drag Queen Story Hour Member Exposed as #LGBTPedophile, Report Says – NewsWars #Houston… https://t.co/JRWEiLCXoT',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'LGBTPedophile', 'indices': [59, 73]},
#       {'text': 'Houston', 'indices': [98, 106]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/JRWEiLCXoT',
#        'expanded_url': 'https://twitter.com/i/web/status/1114193997038276610',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [108, 131]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 736556074564767744,
#      'id_str': '736556074564767744',
#      'name': 'Educate-TV',
#      'screen_name': 'educate_tv',
#      'location': 'United States',
#      'description': '#EDUCATETV #College #Masters #Phd #STEM #Engineering #Science #Tech #BTC. We have the answers!',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 336,
#      'friends_count': 1783,
#      'listed_count': 28,
#      'created_at': 'Sat May 28 13:53:47 +0000 2016',
#      'favourites_count': 2498,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 73489,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/951707959293247488/Ih9Pvoxo_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/951707959293247488/Ih9Pvoxo_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/736556074564767744/1531601687',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 1,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 1,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Sat Aug 08 11:35:56 +0000 2020',
#    'id': 1292061983781449729,
#    'id_str': '1292061983781449729',
#    'text': "@imNanaPatekar @SrBachchan @BeingSalmanKhan @iamsrk @aamir_khan @akshaykumar @iHrithik @ajaydevgn I don't know whet… https://t.co/VqSFCSuzh6",
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'imNanaPatekar',
#       'name': 'Nana Patekar',
#       'id': 1286647406352687104,
#       'id_str': '1286647406352687104',
#       'indices': [0, 14]},
#      {'screen_name': 'SrBachchan',
#       'name': 'Amitabh Bachchan',
#       'id': 145125358,
#       'id_str': '145125358',
#       'indices': [15, 26]},
#      {'screen_name': 'BeingSalmanKhan',
#       'name': 'Salman Khan',
#       'id': 132385468,
#       'id_str': '132385468',
#       'indices': [27, 43]},
#      {'screen_name': 'iamsrk',
#       'name': 'Shah Rukh Khan',
#       'id': 101311381,
#       'id_str': '101311381',
#       'indices': [44, 51]},
#      {'screen_name': 'aamir_khan',
#       'name': 'Aamir Khan',
#       'id': 88856792,
#       'id_str': '88856792',
#       'indices': [52, 63]},
#      {'screen_name': 'akshaykumar',
#       'name': 'Akshay Kumar',
#       'id': 31348594,
#       'id_str': '31348594',
#       'indices': [64, 76]},
#      {'screen_name': 'iHrithik',
#       'name': 'Hrithik Roshan',
#       'id': 113419517,
#       'id_str': '113419517',
#       'indices': [77, 86]},
#      {'screen_name': 'ajaydevgn',
#       'name': 'Ajay Devgn',
#       'id': 65659343,
#       'id_str': '65659343',
#       'indices': [87, 97]}],
#     'urls': [{'url': 'https://t.co/VqSFCSuzh6',
#       'expanded_url': 'https://twitter.com/i/web/status/1292061983781449729',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': 1291769879784112133,
#    'in_reply_to_status_id_str': '1291769879784112133',
#    'in_reply_to_user_id': 1286647406352687104,
#    'in_reply_to_user_id_str': '1286647406352687104',
#    'in_reply_to_screen_name': 'imNanaPatekar',
#    'user': {'id': 830416826861551617,
#     'id_str': '830416826861551617',
#     'name': 'Pranx_always!',
#     'screen_name': 'PriyankaMustafi',
#     'location': 'Pune, India',
#     'description': "Talkative,Passionate about Food,Bollywood&cricket,ambitious, righteous, loyal and funny.Can watch movies I like 100times- that's what makes me special..crazy!",
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 12,
#     'friends_count': 150,
#     'listed_count': 0,
#     'created_at': 'Sat Feb 11 14:02:54 +0000 2017',
#     'favourites_count': 1317,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 127,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1248862637514878976/JgKZWcyQ_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1248862637514878976/JgKZWcyQ_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/830416826861551617/1586586992',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Sat Aug 08 11:35:35 +0000 2020',
#    'id': 1292061895298633730,
#    'id_str': '1292061895298633730',
#    'text': '@Lrihendry @Mark_Geertsma94 #MeToo',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'MeToo', 'indices': [28, 34]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'Lrihendry',
#       'name': 'LORI HENDRY',
#       'id': 129235890,
#       'id_str': '129235890',
#       'indices': [0, 10]},
#      {'screen_name': 'Mark_Geertsma94',
#       'name': 'Mark Geertsma',
#       'id': 919797216188829697,
#       'id_str': '919797216188829697',
#       'indices': [11, 27]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'und', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': 1287382541427716097,
#    'in_reply_to_status_id_str': '1287382541427716097',
#    'in_reply_to_user_id': 129235890,
#    'in_reply_to_user_id_str': '129235890',
#    'in_reply_to_screen_name': 'Lrihendry',
#    'user': {'id': 1207058401,
#     'id_str': '1207058401',
#     'name': 'David Roper',
#     'screen_name': 'davethedrummer7',
#     'location': 'Atlanta, GA',
#     'description': 'Host of Red, White and Buzzed podcast drummer and guitarist for Ht and The Kind,comedian, musician engineer, producer,writer, and shameless promotor',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1021,
#     'friends_count': 1187,
#     'listed_count': 6,
#     'created_at': 'Fri Feb 22 06:38:58 +0000 2013',
#     'favourites_count': 37253,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 11707,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/661160098639671298/ee6zx0uO_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/661160098639671298/ee6zx0uO_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1207058401/1593271044',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': {'id': '7142eb97ae21e839',
#     'url': 'https://api.twitter.com/1.1/geo/id/7142eb97ae21e839.json',
#     'place_type': 'admin',
#     'name': 'Georgia',
#     'full_name': 'Georgia, USA',
#     'country_code': 'US',
#     'country': 'United States',
#     'contained_within': [],
#     'bounding_box': {'type': 'Polygon',
#      'coordinates': [[[-85.605166, 30.355644],
#        [-80.742567, 30.355644],
#        [-80.742567, 35.000771],
#        [-85.605166, 35.000771]]]},
#     'attributes': {}},
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'und'},
#   {'created_at': 'Sat Aug 08 11:34:49 +0000 2020',
#    'id': 1292061700682907649,
#    'id_str': '1292061700682907649',
#    'text': 'RT @toootfarangi: تجاوز فقط فیزیکی نیست.خیلی از موارد تجاوز کلامیه و هر چی اصرار میکنی باز اون ادامه میده. از دیروز که یگانه @yegooneh شجاع…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'toootfarangi',
#       'name': 'توت به ظاهر فرنگی',
#       'id': 255073754,
#       'id_str': '255073754',
#       'indices': [3, 16]},
#      {'screen_name': 'yegooneh',
#       'name': 'یگونه منجیِ عالم',
#       'id': 2859633467,
#       'id_str': '2859633467',
#       'indices': [125, 134]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'fa', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 975402740,
#     'id_str': '975402740',
#     'name': 'موسیو امید🏳',
#     'screen_name': 'MusioOmid',
#     'location': 'به تو چه 😏',
#     'description': '. . . is typing',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 3460,
#     'friends_count': 291,
#     'listed_count': 10,
#     'created_at': 'Wed Nov 28 05:09:54 +0000 2012',
#     'favourites_count': 700546,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 110156,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1284945621833613321/fEm-0hB7_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1284945621833613321/fEm-0hB7_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/975402740/1592860678',
#     'profile_link_color': '94D487',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sat Aug 08 10:52:01 +0000 2020',
#     'id': 1292050931710861314,
#     'id_str': '1292050931710861314',
#     'text': 'تجاوز فقط فیزیکی نیست.خیلی از موارد تجاوز کلامیه و هر چی اصرار میکنی باز اون ادامه میده. از دیروز که یگانه… https://t.co/QeRnRsDq7P',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/QeRnRsDq7P',
#        'expanded_url': 'https://twitter.com/i/web/status/1292050931710861314',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [108, 131]}]},
#     'metadata': {'iso_language_code': 'fa', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 255073754,
#      'id_str': '255073754',
#      'name': 'توت به ظاهر فرنگی',
#      'screen_name': 'toootfarangi',
#      'location': 'Germany',
#      'description': '\u200f\u200f\u200f\u200f\u200fاگه معنی ScheiⓢEgal  رو فهمیدی بیا با من بحث کن.',
#      'url': 'https://t.co/PFxiQzRYO3',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/PFxiQzRYO3',
#          'expanded_url': 'https://t.me/BChatBot?start=sc-8682-8VIMD9O',
#          'display_url': 't.me/BChatBot?start…',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 1836,
#      'friends_count': 757,
#      'listed_count': 10,
#      'created_at': 'Sun Feb 20 16:30:07 +0000 2011',
#      'favourites_count': 45095,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 19889,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '0099B9',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme4/bg.gif',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme4/bg.gif',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1289173854791892992/RF4gpbrT_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1289173854791892992/RF4gpbrT_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/255073754/1389878265',
#      'profile_link_color': '0099B9',
#      'profile_sidebar_border_color': '5ED4DC',
#      'profile_sidebar_fill_color': '95E8EC',
#      'profile_text_color': '3C3940',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 18,
#     'favorite_count': 83,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': True,
#     'lang': 'fa'},
#    'is_quote_status': False,
#    'retweet_count': 18,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'fa'},
#   {'created_at': 'Sat Aug 08 11:34:25 +0000 2020',
#    'id': 1292061601407934469,
#    'id_str': '1292061601407934469',
#    'text': 'Trots op mezelf dat ik de meest donkere momenten uit mijn verleden heb opgeschreven en dat mijn boek Close-up in ok… https://t.co/5eAOs447SB',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/5eAOs447SB',
#       'expanded_url': 'https://twitter.com/i/web/status/1292061601407934469',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'metadata': {'iso_language_code': 'nl', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 919854192428240896,
#     'id_str': '919854192428240896',
#     'name': 'Thysia Huisman',
#     'screen_name': 'thysia_huisman',
#     'location': 'Amsterdam',
#     'description': 'Survivor & Author of Close-Up, about what happened to me as a young model in Paris. Coming this fall. Publisher: #PepperBooks #closeup #silencebreakers #timesup',
#     'url': 'https://t.co/a5312WAILv',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/a5312WAILv',
#         'expanded_url': 'https://www.pepperbooks.nl/boek/close-up/',
#         'display_url': 'pepperbooks.nl/boek/close-up/',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1747,
#     'friends_count': 388,
#     'listed_count': 3,
#     'created_at': 'Mon Oct 16 09:15:04 +0000 2017',
#     'favourites_count': 1428,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 764,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1222809891942866944/pObME8O5_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1222809891942866944/pObME8O5_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/919854192428240896/1593087236',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': True,
#    'quoted_status_id': 1292056949895368706,
#    'quoted_status_id_str': '1292056949895368706',
#    'quoted_status': {'created_at': 'Sat Aug 08 11:15:56 +0000 2020',
#     'id': 1292056949895368706,
#     'id_str': '1292056949895368706',
#     'text': 'Wanneer ze op 18-jarige leeftijd door een bekende modellenscout wordt uitgenodigd in zijn huis in Parijs, twijfelt… https://t.co/aykcw5DuWk',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/aykcw5DuWk',
#        'expanded_url': 'https://twitter.com/i/web/status/1292056949895368706',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [116, 139]}]},
#     'metadata': {'iso_language_code': 'nl', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 3252789161,
#      'id_str': '3252789161',
#      'name': 'Pepper Books',
#      'screen_name': 'Pepperbooks',
#      'location': 'Alkmaar, Nederland',
#      'description': 'Verhalen die er toe doen.',
#      'url': 'https://t.co/tdcSYsCOGB',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/tdcSYsCOGB',
#          'expanded_url': 'http://www.pepperbooks.nl',
#          'display_url': 'pepperbooks.nl',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 674,
#      'friends_count': 652,
#      'listed_count': 13,
#      'created_at': 'Wed May 13 22:01:48 +0000 2015',
#      'favourites_count': 4923,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 3938,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': True,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/614060579121016833/craMaHmh_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/614060579121016833/craMaHmh_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3252789161/1523531535',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 0,
#     'favorite_count': 1,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'nl'},
#    'retweet_count': 0,
#    'favorite_count': 1,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'nl'},
#   {'created_at': 'Sat Aug 08 11:33:37 +0000 2020',
#    'id': 1292061398395170816,
#    'id_str': '1292061398395170816',
#    'text': 'RT @TabibeDoregard: یه متجاوز الزاما یه ادم با دندونای زرد و خنده های تا بناگوش و چشم های خیره نیست\nماها میتونیم با ترویج فرهنگ تجاوز ادمای…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'TabibeDoregard',
#       'name': 'طبیب دوره\u200cگرد',
#       'id': 1024317276563152898,
#       'id_str': '1024317276563152898',
#       'indices': [3, 18]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'fa', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 878355197625585664,
#     'id_str': '878355197625585664',
#     'name': 'Mariii',
#     'screen_name': 'Rosalinmaryyy',
#     'location': 'Islamic Republic of Iran',
#     'description': 'ما را نه غم دوزخ و نه حرص بهشت است',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 189,
#     'friends_count': 158,
#     'listed_count': 1,
#     'created_at': 'Fri Jun 23 20:52:52 +0000 2017',
#     'favourites_count': 84819,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 2460,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1268120233333665792/RpREBwL5_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1268120233333665792/RpREBwL5_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/878355197625585664/1591178399',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sat Aug 08 05:36:00 +0000 2020',
#     'id': 1291971403043024897,
#     'id_str': '1291971403043024897',
#     'text': 'یه متجاوز الزاما یه ادم با دندونای زرد و خنده های تا بناگوش و چشم های خیره نیست\nماها میتونیم با ترویج فرهنگ تجاوز ا… https://t.co/MW4qRvGw6O',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/MW4qRvGw6O',
#        'expanded_url': 'https://twitter.com/i/web/status/1291971403043024897',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'fa', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1024317276563152898,
#      'id_str': '1024317276563152898',
#      'name': 'طبیب دوره\u200cگرد',
#      'screen_name': 'TabibeDoregard',
#      'location': 'Tehran',
#      'description': '@tabibretweeter🌐قبل توییتام«به نظرم»اضافه کنین🌐گاهی اوقات فقط میتونم سریع توییت بنویسم و آفلاین بشم🌐رشته توییت ها👈🏿#رشتوگرد',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 4834,
#      'friends_count': 1946,
#      'listed_count': 16,
#      'created_at': 'Tue Jul 31 15:34:04 +0000 2018',
#      'favourites_count': 18358,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 27071,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1278290627453693953/7-nI-eSK_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1278290627453693953/7-nI-eSK_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1024317276563152898/1538057761',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 26,
#     'favorite_count': 176,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'fa'},
#    'is_quote_status': False,
#    'retweet_count': 26,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'fa'},
#   {'created_at': 'Sat Aug 08 11:32:35 +0000 2020',
#    'id': 1292061138562297856,
#    'id_str': '1292061138562297856',
#    'text': 'RT @tara_cox_writer: My Trouble Texas Style series @literotica courts controversy ripped from the headlines:\n\nCorporate corruption\nRape tra…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'tara_cox_writer',
#       'name': 'Tara Cox - Writer',
#       'id': 129500771,
#       'id_str': '129500771',
#       'indices': [3, 19]},
#      {'screen_name': 'literotica',
#       'name': 'Literotica',
#       'id': 61736910,
#       'id_str': '61736910',
#       'indices': [51, 62]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1142786125,
#     'id_str': '1142786125',
#     'name': 'John Shirey',
#     'screen_name': 'jeshir99',
#     'location': 'Mentor-on-the-Lake, OH',
#     'description': 'I am a retired chemist with five children and seven grandchildren with lots of time to spend on writing #science, #sciencefiction, #fantasy, #paranormal',
#     'url': 'https://t.co/qL8nIugXAD',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/qL8nIugXAD',
#         'expanded_url': 'http://jeshi-99-science.com',
#         'display_url': 'jeshi-99-science.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 3196,
#     'friends_count': 4905,
#     'listed_count': 1203,
#     'created_at': 'Sat Feb 02 16:00:59 +0000 2013',
#     'favourites_count': 1048,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 25378,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C6E2EE',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme2/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme2/bg.gif',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/3203643233/e24d3615dce8aecd6693f49d5008c75b_normal.jpeg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/3203643233/e24d3615dce8aecd6693f49d5008c75b_normal.jpeg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1142786125/1582221382',
#     'profile_link_color': '1F98C7',
#     'profile_sidebar_border_color': 'C6E2EE',
#     'profile_sidebar_fill_color': 'DAECF4',
#     'profile_text_color': '663B12',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sat Aug 08 01:11:00 +0000 2020',
#     'id': 1291904711155744770,
#     'id_str': '1291904711155744770',
#     'text': 'My Trouble Texas Style series @literotica courts controversy ripped from the headlines:\n\nCorporate corruption\nRape… https://t.co/yOFmHAaJXU',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'literotica',
#        'name': 'Literotica',
#        'id': 61736910,
#        'id_str': '61736910',
#        'indices': [30, 41]}],
#      'urls': [{'url': 'https://t.co/yOFmHAaJXU',
#        'expanded_url': 'https://twitter.com/i/web/status/1291904711155744770',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [116, 139]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 129500771,
#      'id_str': '129500771',
#      'name': 'Tara Cox - Writer',
#      'screen_name': 'tara_cox_writer',
#      'location': 'Swansea, Wales',
#      'description': 'Real-life, hot sex, deep meaning\n#creator, #Writer of #literary #erotica \n#neurodivergent #homemaker with 100s of people in my head trying to write them out',
#      'url': 'https://t.co/4DfwduYxzu',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/4DfwduYxzu',
#          'expanded_url': 'http://taracoxwriter.com',
#          'display_url': 'taracoxwriter.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 3378,
#      'friends_count': 3449,
#      'listed_count': 68,
#      'created_at': 'Sun Apr 04 14:04:12 +0000 2010',
#      'favourites_count': 14078,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 7160,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1146657101562994688/Jj34Iadg_normal.png',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1146657101562994688/Jj34Iadg_normal.png',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/129500771/1591350248',
#      'profile_link_color': '9266CC',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 1,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 1,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Sat Aug 08 11:31:47 +0000 2020',
#    'id': 1292060938095464451,
#    'id_str': '1292060938095464451',
#    'text': 'RT @Brooklynn187: @Baelizean You know why🥴🥴 the fact she was one of the faces for #metoo ... it’s a cold world',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'metoo', 'indices': [82, 88]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'Brooklynn187',
#       'name': 'Brooklynn💜💜💜',
#       'id': 1086868948086341633,
#       'id_str': '1086868948086341633',
#       'indices': [3, 16]},
#      {'screen_name': 'Baelizean',
#       'name': 'Des Thee Hellion🇧🇿',
#       'id': 98053865,
#       'id_str': '98053865',
#       'indices': [18, 28]}],
# ...
#      'has_extended_profile': True,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 1,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 1,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Sat Aug 08 11:31:43 +0000 2020',
#    'id': 1292060921624485889,
#    'id_str': '1292060921624485889',
#    'text': '@billkilgore_ @PutaCasquero Kilgore yo si te creo #MeToo',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'MeToo', 'indices': [50, 56]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'billkilgore_',
#       'name': 'Kilgore',
#       'id': 819246908191494144,
#       'id_str': '819246908191494144',
#       'indices': [0, 13]},
#      {'screen_name': 'PutaCasquero',
#       'name': 'PutaCasquero',
#       'id': 1003260694333095936,
#       'id_str': '1003260694333095936',
#       'indices': [14, 27]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'ht', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': 1292033539538657288,
#    'in_reply_to_status_id_str': '1292033539538657288',
#    'in_reply_to_user_id': 819246908191494144,
#    'in_reply_to_user_id_str': '819246908191494144',
#    'in_reply_to_screen_name': 'billkilgore_',
#    'user': {'id': 1492733010,
#     'id_str': '1492733010',
#     'name': 'Toni',
#     'screen_name': 'toniciudad_13',
#     'location': 'A Coruña',
#     'description': 'Preso de la Luna y toda la mierda que me seda',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 2839,
#     'friends_count': 659,
#     'listed_count': 13,
#     'created_at': 'Sat Jun 08 12:10:25 +0000 2013',
#     'favourites_count': 18269,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 157811,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '131516',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#     'profile_background_tile': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1279210540309590016/bE03hfs3_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1279210540309590016/bE03hfs3_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1492733010/1479072688',
#     'profile_link_color': '080808',
#     'profile_sidebar_border_color': 'EEEEEE',
#     'profile_sidebar_fill_color': 'EFEFEF',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'regular'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'ht'},
#   {'created_at': 'Sat Aug 08 11:31:16 +0000 2020',
#    'id': 1292060805945528321,
#    'id_str': '1292060805945528321',
#    'text': '@MsAvaArmstrong #MeToo',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'MeToo', 'indices': [16, 22]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'MsAvaArmstrong',
#       'name': 'Ava Armstrong, Author',
#       'id': 2449913803,
#       'id_str': '2449913803',
#       'indices': [0, 15]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'und', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>',
#    'in_reply_to_status_id': 1291837960397230080,
#    'in_reply_to_status_id_str': '1291837960397230080',
#    'in_reply_to_user_id': 2449913803,
#    'in_reply_to_user_id_str': '2449913803',
#    'in_reply_to_screen_name': 'MsAvaArmstrong',
#    'user': {'id': 113234784,
#     'id_str': '113234784',
#     'name': 'RECLAIMING MY COUNTRY!!!',
#     'screen_name': 'BarrySux',
#     'location': 'Texas',
#     'description': "Clean & sober since 7/11/87. World's tallest Pygmy. Skinniest person in my WeightWatchers group. Liberals are using #COVID to damage #PresidentTrump #MAGA #KAG",
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 4336,
#     'friends_count': 4893,
#     'listed_count': 136,
#     'created_at': 'Thu Feb 11 04:00:16 +0000 2010',
#     'favourites_count': 9938,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 37009,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '244969',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1288256128606928896/Hhi0QWz6_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1288256128606928896/Hhi0QWz6_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/113234784/1545241178',
#     'profile_link_color': '112438',
#     'profile_sidebar_border_color': '5C503A',
#     'profile_sidebar_fill_color': 'B58421',
#     'profile_text_color': '333333',
#     'profile_use_background_image': False,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'und'},
#   {'created_at': 'Sat Aug 08 11:31:06 +0000 2020',
#    'id': 1292060763830603776,
#    'id_str': '1292060763830603776',
#    'text': 'RT @TaraKh5: #metoo\nدوست ناشناسی از من خواستن متن پیامشون بذارم. \nسلام. من چند بار تو زندگیم بهم تجاوز شده که به دلایلی نمی\u200cتونم توی صفحه خ…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'metoo', 'indices': [13, 19]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'TaraKh5',
#       'name': 'تاریشکا',
#       'id': 4697911333,
#       'id_str': '4697911333',
#       'indices': [3, 11]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'fa', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1152221132143173634,
#     'id_str': '1152221132143173634',
#     'name': 'saeed brr',
#     'screen_name': 'saeedbrr',
#     'location': '',
#     'description': '\u200f\u200f\u200f\u200f\u200f\u200f\u200fامید بذر هویت ماست.\n\nحقوق عمومی چی\nhttps://t.co/uHlLQZcVE5\u200e…\u200e\u200e',
#     'url': None,
#     'entities': {'description': {'urls': [{'url': 'https://t.co/uHlLQZcVE5',
#         'expanded_url': 'http://telegram.me/HarfBeManBot?s',
#         'display_url': 'telegram.me/HarfBeManBot?s',
#         'indices': [42, 65]}]}},
#     'protected': False,
#     'followers_count': 1050,
#     'friends_count': 949,
#     'listed_count': 5,
#     'created_at': 'Fri Jul 19 14:18:19 +0000 2019',
#     'favourites_count': 31642,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 8748,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1155202002022014976/1aQR3_Pq_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1155202002022014976/1aQR3_Pq_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Fri Aug 07 23:55:00 +0000 2020',
#     'id': 1291885587218259969,
#     'id_str': '1291885587218259969',
#     'text': '#metoo\nدوست ناشناسی از من خواستن متن پیامشون بذارم. \nسلام. من چند بار تو زندگیم بهم تجاوز شده که به دلایلی نمی\u200cتونم… https://t.co/iIr1cyNCll',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'metoo', 'indices': [0, 6]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/iIr1cyNCll',
#        'expanded_url': 'https://twitter.com/i/web/status/1291885587218259969',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'fa', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 4697911333,
#      'id_str': '4697911333',
#      'name': 'تاریشکا',
#      'screen_name': 'TaraKh5',
#      'location': 'تهران ',
#      'description': '\u200f\u200f\u200f\u200f\u200f\u200f\u200f\u200f\u200fروانشناس بالینی',
#      'url': 'https://t.co/FUIpgU2ZfW',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/FUIpgU2ZfW',
#          'expanded_url': 'https://telegram.me/harfbemanbot?start=MTA5MjI3MDYy',
#          'display_url': 'telegram.me/harfbemanbot?s…',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 5077,
#      'friends_count': 774,
#      'listed_count': 16,
#      'created_at': 'Sat Jan 02 18:41:32 +0000 2016',
#      'favourites_count': 325024,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 29750,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1252716614065229835/iN3Bc2HI_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1252716614065229835/iN3Bc2HI_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/4697911333/1572548674',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 35,
#     'favorite_count': 297,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'fa'},
#    'is_quote_status': False,
#    'retweet_count': 35,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'fa'},
#   {'created_at': 'Sat Aug 08 11:30:27 +0000 2020',
#    'id': 1292060603574624257,
#    'id_str': '1292060603574624257',
#    'text': 'Criando hijos en la era #Metoo\n\nhttps://t.co/Scp4VDCced',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'Metoo', 'indices': [24, 30]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/Scp4VDCced',
#       'expanded_url': 'https://bit.ly/2Xkg04h',
#       'display_url': 'bit.ly/2Xkg04h',
#       'indices': [32, 55]}]},
#    'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#    'source': '<a href="https://www.hootsuite.com" rel="nofollow">Hootsuite Inc.</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 42832810,
#     'id_str': '42832810',
#     'name': 'El Diario',
#     'screen_name': 'eldiario',
#     'location': 'Caracas, Venezuela',
#     'description': '#TeExplicamosLaNoticia 🇻🇪 Medio venezolano que hace periodismo con carácter y sin censura 📰 ¡Únete a la conversación! 🗣',
#     'url': 'https://t.co/8Cqd3HGXFW',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/8Cqd3HGXFW',
#         'expanded_url': 'http://eldiario.com',
#         'display_url': 'eldiario.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 927806,
#     'friends_count': 91908,
#     'listed_count': 3769,
#     'created_at': 'Wed May 27 06:50:45 +0000 2009',
#     'favourites_count': 3486,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': True,
#     'statuses_count': 662054,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '510800',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme19/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme19/bg.gif',
#     'profile_background_tile': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1278095174967726081/732uk04R_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1278095174967726081/732uk04R_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/42832810/1572839202',
#     'profile_link_color': 'A16A23',
#     'profile_sidebar_border_color': '3D0702',
#     'profile_sidebar_fill_color': '2C1703',
#     'profile_text_color': 'E0912A',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'regular'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'es'}],
#  'search_metadata': {'completed_in': 0.085,
#   'max_id': 1292062846415589377,
#   'max_id_str': '1292062846415589377',
#   'next_results': '?max_id=1292060603574624256&q=%23MeToo&include_entities=1',
#   'query': '%23MeToo',
#   'refresh_url': '?since_id=1292062846415589377&q=%23MeToo&include_entities=1',
#   'count': 15,
#   'since_id': 0,
#   'since_id_str': '0'}}

# %% [markdown]
# **Step 2:  Adding Parameters to Your Query String**

# %% [markdown]
# Query strings basically have two parts:
#
#  - The `?` initiates the beginning of the API call, and basically says 'everything that follows this will encode something about the information that's going to get returned to you'.
#  - What follows that is are a bunch of symbols followed by `=` signs.  These are parameters.
#  - So when you make an api call to `'https://api.twitter.com/1.1/search/tweets.json?q=My%20Search%20Term`, the `q` is a paremeter.
#  - You can add multiple paremeters to a query string. They are separated by `&`. They dictate what kinds of results are returned.
#   - For example, a parameter you can use in Twitter's search API is `count`, which tells you how many results to return.  The default is 15, but you can return up to 100.  So if we wanted to search for tweets and return 50 results our query string would look like the following:
#     `https://api.twitter.com/1.1/search/tweets.json?q=My%20Search%20String&count=50`
#   - You can add as many of these parameters to your string as you'd like.  So for example, if we wanted to include parameters for `count` and `result_type`, we could do the following: `https://api.twitter.com/1.1/search/tweets.json?q=My%20Search%20String&count=50&result_type=mixed`
#
# To get the hang of this, try searching for tweets that mention the hashtag `#DeepLearning`, and return 75 results.

# %%
search = '?q=%23DeepLearning&count=75'

search_results = requests.get(base_url + search, auth=auth).json()
search_results
# Out:
# {'statuses': [{'created_at': 'Sat Aug 08 11:43:47 +0000 2020',
#    'id': 1292063957184688128,
#    'id_str': '1292063957184688128',
#    'text': 'RT @arXiv_Daily: PatchNets: Patch-Based Generalizable Deep Implicit 3D Shape Representations\nhttps://t.co/3GmsSkOrYG\nby Edgar Tretschk et a…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'arXiv_Daily',
#       'name': 'arXiv Daily',
#       'id': 945496245530869760,
#       'id_str': '945496245530869760',
#       'indices': [3, 15]}],
#     'urls': [{'url': 'https://t.co/3GmsSkOrYG',
#       'expanded_url': 'https://deepai.org/publication/patchnets-patch-based-generalizable-deep-implicit-3d-shape-representations',
#       'display_url': 'deepai.org/publication/pa…',
#       'indices': [93, 116]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 27614577,
#     'id_str': '27614577',
#     'name': 'KageKirin #blm',
#     'screen_name': 'KageKirin',
#     'location': 'Tokyo, Japan',
#     'description': 'Ninja graphics engineer, as in doing graphics work by day and studying Bujinkan by night. #blackLivesMatter #againstPoliceBrutality',
#     'url': 'https://t.co/EkY9Ubtjds',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/EkY9Ubtjds',
#         'expanded_url': 'http://kagekirin.gitlab.io',
#         'display_url': 'kagekirin.gitlab.io',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1341,
#     'friends_count': 4852,
#     'listed_count': 103,
#     'created_at': 'Mon Mar 30 10:26:18 +0000 2009',
#     'favourites_count': 38819,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 51282,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/296100212/logo_kreis_weiss_oben_rechts_normal.png',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/296100212/logo_kreis_weiss_oben_rechts_normal.png',
#     'profile_link_color': '1B95E0',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sat Aug 08 11:08:02 +0000 2020',
#     'id': 1292054960931135488,
#     'id_str': '1292054960931135488',
#     'text': 'PatchNets: Patch-Based Generalizable Deep Implicit 3D Shape Representations\nhttps://t.co/3GmsSkOrYG\nby Edgar Tretsc… https://t.co/dYAYIn6Xn7',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/3GmsSkOrYG',
#        'expanded_url': 'https://deepai.org/publication/patchnets-patch-based-generalizable-deep-implicit-3d-shape-representations',
#        'display_url': 'deepai.org/publication/pa…',
#        'indices': [76, 99]},
#       {'url': 'https://t.co/dYAYIn6Xn7',
#        'expanded_url': 'https://twitter.com/i/web/status/1292054960931135488',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://deepai.org/" rel="nofollow">ArXiv Daily</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 945496245530869760,
#      'id_str': '945496245530869760',
#      'name': 'arXiv Daily',
#      'screen_name': 'arXiv_Daily',
#      'location': '1.5 AU',
#      'description': "Daily feed of this week's top research articles published to https://t.co/ZBNrZVbzEn. #DataScience, #ML, & #ArtificialIntelligence. Curated by @Deep__AI",
#      'url': 'https://t.co/6ufGggQ9M5',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/6ufGggQ9M5',
#          'expanded_url': 'https://deepai.org/research',
#          'display_url': 'deepai.org/research',
#          'indices': [0, 23]}]},
#       'description': {'urls': [{'url': 'https://t.co/ZBNrZVbzEn',
#          'expanded_url': 'http://arXiv.org',
#          'display_url': 'arXiv.org',
#          'indices': [61, 84]}]}},
#      'protected': False,
#      'followers_count': 29262,
#      'friends_count': 2007,
#      'listed_count': 367,
#      'created_at': 'Tue Dec 26 03:27:26 +0000 2017',
#      'favourites_count': 329,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 15078,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/945497303036526593/s9LSNZ9p_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/945497303036526593/s9LSNZ9p_normal.jpg',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 2,
#     'favorite_count': 7,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 2,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Sat Aug 08 11:43:31 +0000 2020',
#    'id': 1292063889484546054,
#    'id_str': '1292063889484546054',
#    'text': 'RT @nigewillson: The problems Artificial Intelligence has today go back centuries https://t.co/7N9PN4UWUb\n#ai #artificialintelligence #Mach…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'ai', 'indices': [106, 109]},
#      {'text': 'artificialintelligence', 'indices': [110, 133]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'nigewillson',
#       'name': 'Nige Willson',
#       'id': 228040559,
#       'id_str': '228040559',
#       'indices': [3, 15]}],
#     'urls': [{'url': 'https://t.co/7N9PN4UWUb',
#       'expanded_url': 'https://bit.ly/3icFMzN',
#       'display_url': 'bit.ly/3icFMzN',
#       'indices': [82, 105]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://dataminingthemoney.com " rel="nofollow">datareadinfo</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1073351604450050048,
#     'id_str': '1073351604450050048',
#     'name': 'Black People Data',
#     'screen_name': 'blackpeopledata',
#     'location': 'Global',
#     'description': 'We are passionate about publishing articles that help readers understand how topics of interest impact black people in America and abroad.Publish today!#article',
#     'url': 'https://t.co/tJTaC5UxDH',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/tJTaC5UxDH',
#         'expanded_url': 'https://blackpeopledata.com/',
#         'display_url': 'blackpeopledata.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 959,
#     'friends_count': 791,
#     'listed_count': 11,
#     'created_at': 'Thu Dec 13 22:58:59 +0000 2018',
#     'favourites_count': 284,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 28891,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1240230518056239110/7RuR_cbE_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1240230518056239110/7RuR_cbE_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1073351604450050048/1584528976',
#     'profile_link_color': '981CEB',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sat Aug 08 11:40:03 +0000 2020',
#     'id': 1292063017732112390,
#     'id_str': '1292063017732112390',
#     'text': 'The problems Artificial Intelligence has today go back centuries https://t.co/7N9PN4UWUb\n#ai… https://t.co/LKMzUYeH6M',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'ai', 'indices': [89, 92]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/7N9PN4UWUb',
#        'expanded_url': 'https://bit.ly/3icFMzN',
#        'display_url': 'bit.ly/3icFMzN',
#        'indices': [65, 88]},
#       {'url': 'https://t.co/LKMzUYeH6M',
#        'expanded_url': 'https://twitter.com/i/web/status/1292063017732112390',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [94, 117]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://buffer.com" rel="nofollow">Buffer</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 228040559,
#      'id_str': '228040559',
#      'name': 'Nige Willson',
#      'screen_name': 'nigewillson',
#      'location': 'ringwood, uk',
#      'description': 'influencer & advisor on #artificialintelligence, #innovation & #technology, founder https://t.co/TUfZ40kYbe  Co-founder @WeandAI, ex #CTO - #aiethics above all #human !',
#      'url': 'https://t.co/eQiAlb6jqN',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/eQiAlb6jqN',
#          'expanded_url': 'http://www.awakenai.org',
#          'display_url': 'awakenai.org',
#          'indices': [0, 23]}]},
#       'description': {'urls': [{'url': 'https://t.co/TUfZ40kYbe',
#          'expanded_url': 'http://awakenAI.org',
#          'display_url': 'awakenAI.org',
#          'indices': [84, 107]}]}},
#      'protected': False,
#      'followers_count': 55973,
#      'friends_count': 49555,
#      'listed_count': 1665,
#      'created_at': 'Sat Dec 18 15:00:12 +0000 2010',
#      'favourites_count': 45478,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 58807,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme7/bg.gif',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme7/bg.gif',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1085251590997622784/x9mWVQ1d_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1085251590997622784/x9mWVQ1d_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/228040559/1591347293',
#      'profile_link_color': 'E81C4F',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 2,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 2,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Sat Aug 08 11:43:26 +0000 2020',
#    'id': 1292063870106963970,
#    'id_str': '1292063870106963970',
#    'text': 'RT @ipfconline1: Object Detection Algorithms: A #DeepLearning Guide for Beginners\n\nhttps://t.co/Exbf1MVo0w @LionbridgeAI\n#HealthTech #Covid…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'DeepLearning', 'indices': [48, 61]},
#      {'text': 'HealthTech', 'indices': [121, 132]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'ipfconline1',
#       'name': 'ipfconline',
#       'id': 705539763349164032,
#       'id_str': '705539763349164032',
#       'indices': [3, 15]},
#      {'screen_name': 'LionbridgeAI',
#       'name': 'Lionbridge AI',
#       'id': 16648808,
#       'id_str': '16648808',
#       'indices': [107, 120]}],
#     'urls': [{'url': 'https://t.co/Exbf1MVo0w',
#       'expanded_url': 'https://buff.ly/2YV0tbf',
#       'display_url': 'buff.ly/2YV0tbf',
#       'indices': [83, 106]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1079458941606772738,
#     'id_str': '1079458941606772738',
#     'name': 'JOSE PEREZ JR 🇧🇷 🇵🇹 🇪🇺',
#     'screen_name': 'JOSEPEREZJR01',
#     'location': 'Born in SP, lives in Brasilia',
#     'description': 'Interests: #Business, #Economy, #Finance, #Stocks, #Markets, #DigitalMarketing, #DataScience, #Science, #IOT, #AI, #ML, #NewTech, #Industry40, #SmartCities,#Art',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1120,
#     'friends_count': 949,
#     'listed_count': 14,
#     'created_at': 'Sun Dec 30 19:27:21 +0000 2018',
#     'favourites_count': 34011,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 40442,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1263183423235067906/hKgZaHOD_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1263183423235067906/hKgZaHOD_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1079458941606772738/1592164174',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sat Aug 08 11:00:18 +0000 2020',
#     'id': 1292053014929383425,
#     'id_str': '1292053014929383425',
#     'text': 'Object Detection Algorithms: A #DeepLearning Guide for Beginners\n\nhttps://t.co/Exbf1MVo0w @LionbridgeAI\n#HealthTech… https://t.co/dCsGTI5H6o',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'DeepLearning', 'indices': [31, 44]},
#       {'text': 'HealthTech', 'indices': [104, 115]}],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'LionbridgeAI',
#        'name': 'Lionbridge AI',
#        'id': 16648808,
#        'id_str': '16648808',
#        'indices': [90, 103]}],
#      'urls': [{'url': 'https://t.co/Exbf1MVo0w',
#        'expanded_url': 'https://buff.ly/2YV0tbf',
#        'display_url': 'buff.ly/2YV0tbf',
#        'indices': [66, 89]},
#       {'url': 'https://t.co/dCsGTI5H6o',
#        'expanded_url': 'https://twitter.com/i/web/status/1292053014929383425',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://twittimer.com" rel="nofollow">Twittimer</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 705539763349164032,
#      'id_str': '705539763349164032',
#      'name': 'ipfconline',
#      'screen_name': 'ipfconline1',
#      'location': 'Marseille, France',
#      'description': 'Digital Transformation Consulting \n#AI #MachineLearning #DeepLearning \n#DataScience #AIEthics\n#CloudComputing #Fintech\n#DigitalMarketing',
#      'url': 'https://t.co/AWsrN4R5NF',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/AWsrN4R5NF',
#          'expanded_url': 'http://ipfconline.fr/contacts-eng.html',
#          'display_url': 'ipfconline.fr/contacts-eng.h…',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 112750,
#      'friends_count': 106171,
#      'listed_count': 7869,
#      'created_at': 'Thu Mar 03 23:46:02 +0000 2016',
#      'favourites_count': 134125,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 171065,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/729065804004769793/St2_Pum9_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/729065804004769793/St2_Pum9_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/705539763349164032/1543420399',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 3,
#     'favorite_count': 1,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 3,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Sat Aug 08 11:43:17 +0000 2020',
#    'id': 1292063829665480705,
#    'id_str': '1292063829665480705',
#    'text': 'RT @WhiteheartVic: @_asifbhat_ @quasagroup Smart! Biological  systems are the most cost efficient. Nature is cost efficient. We should look…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'WhiteheartVic',
#       'name': 'Victoria Whiteheart',
#       'id': 1268339456404226048,
#       'id_str': '1268339456404226048',
#       'indices': [3, 17]},
#      {'screen_name': '_asifbhat_',
#       'name': 'Asif Bhat',
#       'id': 1170802004655894528,
#       'id_str': '1170802004655894528',
#       'indices': [19, 30]},
#      {'screen_name': 'quasagroup',
#       'name': 'QUASA',
#       'id': 842120626143911939,
#       'id_str': '842120626143911939',
#       'indices': [31, 42]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1284341999487856640,
#     'id_str': '1284341999487856640',
#     'name': 'JESUSCHRISTMARID JENNIEKIMCROSBY',
#     'screen_name': 'JESUSCHRISTMAR5',
#     'location': 'Chicago, IL',
#     'description': '@Spaceship_Jesus 2013 @BarackObama Received @JcMarid @Indiagoldpolicy by @PmoIndia  & WANT MY #TREASURECHESTTIMEPIECES #IMMEDIATEFAMILY & #HUMANITY @UNSC @NATO',
#     'url': 'https://t.co/zjoYWVbWWl',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/zjoYWVbWWl',
#         'expanded_url': 'http://www.Inventionland.com',
#         'display_url': 'Inventionland.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 137,
#     'friends_count': 3878,
#     'listed_count': 0,
#     'created_at': 'Sat Jul 18 04:19:46 +0000 2020',
#     'favourites_count': 4503,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 6577,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1291514579227496448/TvAt-Sg6_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1291514579227496448/TvAt-Sg6_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1284341999487856640/1596547214',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Tue Aug 04 01:22:15 +0000 2020',
#     'id': 1290457993667129346,
#     'id_str': '1290457993667129346',
#     'text': '@_asifbhat_ @quasagroup Smart! Biological  systems are the most cost efficient. Nature is cost efficient. We should… https://t.co/XmbaQrvEFu',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': '_asifbhat_',
#        'name': 'Asif Bhat',
#        'id': 1170802004655894528,
#        'id_str': '1170802004655894528',
#        'indices': [0, 11]},
#       {'screen_name': 'quasagroup',
#        'name': 'QUASA',
#        'id': 842120626143911939,
#        'id_str': '842120626143911939',
#        'indices': [12, 23]}],
#      'urls': [{'url': 'https://t.co/XmbaQrvEFu',
#        'expanded_url': 'https://twitter.com/i/web/status/1290457993667129346',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': 1290438567559340032,
#     'in_reply_to_status_id_str': '1290438567559340032',
#     'in_reply_to_user_id': 1170802004655894528,
#     'in_reply_to_user_id_str': '1170802004655894528',
#     'in_reply_to_screen_name': '_asifbhat_',
#     'user': {'id': 1268339456404226048,
#      'id_str': '1268339456404226048',
#      'name': 'Victoria Whiteheart',
#      'screen_name': 'WhiteheartVic',
#      'location': 'Promoting the #Otherness ',
#      'description': 'Bringing humanity in robotics is the most crucial  mission of scientists, businesses and governments in the next phase of human evolution.\nPh.D., MA, MTS.4Lang',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 435,
#      'friends_count': 824,
#      'listed_count': 9,
#      'created_at': 'Thu Jun 04 00:31:54 +0000 2020',
#      'favourites_count': 2845,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 2567,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1268347384511201283/CHCU-bga_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1268347384511201283/CHCU-bga_normal.jpg',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 12,
#     'favorite_count': 5,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 12,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Sat Aug 08 11:43:02 +0000 2020',
#    'id': 1292063770383020033,
#    'id_str': '1292063770383020033',
#    'text': 'RT @SpirosMargaris: The #US Has #AI Competition \n\nAll Wrong\n\nhttps://t.co/XXVNwyD5Iu #fintech #ArtificialIntelligence #MachineLearning #Dee…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'US', 'indices': [24, 27]},
#      {'text': 'AI', 'indices': [32, 35]},
#      {'text': 'fintech', 'indices': [85, 93]},
#      {'text': 'ArtificialIntelligence', 'indices': [94, 117]},
#      {'text': 'MachineLearning', 'indices': [118, 134]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'SpirosMargaris',
#       'name': 'Spiros Margaris',
#       'id': 2711212681,
#       'id_str': '2711212681',
#       'indices': [3, 18]}],
#     'urls': [{'url': 'https://t.co/XXVNwyD5Iu',
#       'expanded_url': 'https://fam.ag/2DHgVoK',
#       'display_url': 'fam.ag/2DHgVoK',
#       'indices': [61, 84]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 908230076,
#     'id_str': '908230076',
#     'name': 'Analytics India Magazine',
#     'screen_name': 'Analyticsindiam',
#     'location': 'Bengaluru, Karnataka',
#     'description': "India's leading publisher chronicling advances in #Analytics, #BigData, #ArtificialIntelligence and #DataScience.",
#     'url': 'https://t.co/FfMLw6uyWY',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/FfMLw6uyWY',
#         'expanded_url': 'https://analyticsindiamag.com',
#         'display_url': 'analyticsindiamag.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 11098,
#     'friends_count': 326,
#     'listed_count': 245,
#     'created_at': 'Sat Oct 27 14:31:20 +0000 2012',
#     'favourites_count': 14189,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 16677,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1190136698962894849/NNdyVORO_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1190136698962894849/NNdyVORO_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/908230076/1594370322',
#     'profile_link_color': '1B95E0',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sat Aug 08 05:09:08 +0000 2020',
#     'id': 1291964638767337472,
#     'id_str': '1291964638767337472',
#     'text': 'The #US Has #AI Competition \n\nAll Wrong\n\nhttps://t.co/XXVNwyD5Iu #fintech #ArtificialIntelligence #MachineLearning… https://t.co/l02MfkUD9R',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'US', 'indices': [4, 7]},
#       {'text': 'AI', 'indices': [12, 15]},
#       {'text': 'fintech', 'indices': [65, 73]},
#       {'text': 'ArtificialIntelligence', 'indices': [74, 97]},
#       {'text': 'MachineLearning', 'indices': [98, 114]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/XXVNwyD5Iu',
#        'expanded_url': 'https://fam.ag/2DHgVoK',
#        'display_url': 'fam.ag/2DHgVoK',
#        'indices': [41, 64]},
#       {'url': 'https://t.co/l02MfkUD9R',
#        'expanded_url': 'https://twitter.com/i/web/status/1291964638767337472',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [116, 139]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://buffer.com" rel="nofollow">Buffer</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 2711212681,
#      'id_str': '2711212681',
#      'name': 'Spiros Margaris',
#      'screen_name': 'SpirosMargaris',
#      'location': 'All Over the World',
#      'description': '#VC #Futurist | @wefoxHQ @SparkLabsGlobal @ai_mediastalker @canopyrent @yieldgrowth @F10_accelerator | No.1 #Fintech Influencer @Onalytica #AI | @TEDx',
#      'url': 'https://t.co/PeTBLwijX6',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/PeTBLwijX6',
#          'expanded_url': 'http://www.MargarisVentures.com',
#          'display_url': 'MargarisVentures.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 101269,
#      'friends_count': 14625,
#      'listed_count': 5512,
#      'created_at': 'Wed Aug 06 05:20:16 +0000 2014',
#      'favourites_count': 168951,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': True,
#      'statuses_count': 194997,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '3B94D9',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1080518156932825089/Elhx7SXw_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1080518156932825089/Elhx7SXw_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2711212681/1596036150',
#      'profile_link_color': '1C2841',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 9,
#     'favorite_count': 6,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 9,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Sat Aug 08 11:42:36 +0000 2020',
#    'id': 1292063660312068096,
#    'id_str': '1292063660312068096',
#    'text': 'RT @CatherineAdenle: Artificial intelligence today: What’s hype and what’s real? Two decades into the #AI revolution, #deeplearning is beco…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'AI', 'indices': [102, 105]},
#      {'text': 'deeplearning', 'indices': [118, 131]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'CatherineAdenle',
#       'name': 'Catherine Adenle',
#       'id': 68433676,
#       'id_str': '68433676',
#       'indices': [3, 19]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 864481143839748097,
#     'id_str': '864481143839748097',
#     'name': 'MercyLord',
#     'screen_name': 'ibileyearegbes3',
#     'location': 'Global Woman',
#     'description': 'Pretty chilled, but catch me out here for #Tech news, #ArtificialIntelligence, virtual tweet jabs at political nincompoops, sharing quality career tips & hacks.',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 191,
#     'friends_count': 520,
#     'listed_count': 19,
#     'created_at': 'Tue May 16 14:02:20 +0000 2017',
#     'favourites_count': 28560,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 24860,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/864488907768868864/h1PfXNbf_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/864488907768868864/h1PfXNbf_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/864481143839748097/1494945138',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sat Aug 08 10:30:57 +0000 2020',
#     'id': 1292045628516651009,
#     'id_str': '1292045628516651009',
#     'text': 'Artificial intelligence today: What’s hype and what’s real? Two decades into the #AI revolution, #deeplearning is b… https://t.co/aNszkByfIE',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'AI', 'indices': [81, 84]},
#       {'text': 'deeplearning', 'indices': [97, 110]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/aNszkByfIE',
#        'expanded_url': 'https://twitter.com/i/web/status/1292045628516651009',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://www.linkedin.com/" rel="nofollow">LinkedIn</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 68433676,
#      'id_str': '68433676',
#      'name': 'Catherine Adenle',
#      'screen_name': 'CatherineAdenle',
#      'location': 'England, United Kingdom',
#      'description': "Founder, Catherine's Career Corner, Author, #Tech Enthusiast, #AI #ML #Data, #Cybersecurity, Certified #ChangeManagement Professional, #Careeradvice, ❤️ Family",
#      'url': 'https://t.co/nuviHfs0PY',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/nuviHfs0PY',
#          'expanded_url': 'https://catherinescareercorner.com',
#          'display_url': 'catherinescareercorner.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 34779,
#      'friends_count': 2241,
#      'listed_count': 769,
#      'created_at': 'Mon Aug 24 15:37:04 +0000 2009',
#      'favourites_count': 40960,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 23188,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '7DBFED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme12/bg.gif',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme12/bg.gif',
#      'profile_background_tile': True,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/476740017432584192/f_Wc8SVX_normal.jpeg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/476740017432584192/f_Wc8SVX_normal.jpeg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/68433676/1398344975',
#      'profile_link_color': '3D8EE0',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '1C1C1C',
#      'profile_text_color': '5C91B9',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 3,
#     'favorite_count': 2,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 3,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Sat Aug 08 11:42:22 +0000 2020',
#    'id': 1292063599750516736,
#    'id_str': '1292063599750516736',
#    'text': 'RT @SmokeyGunBarrel: Finally, I landed a job at a startup with a great salary and most likely will end up being a partner in the same compa…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'SmokeyGunBarrel',
#       'name': 'Ankur Sinha',
#       'id': 1158744568440868864,
#       'id_str': '1158744568440868864',
#       'indices': [3, 19]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 94290760,
#     'id_str': '94290760',
#     'name': 'Wayne Thogoto',
#     'screen_name': 'thogoto',
#     'location': 'Nairobi, kenya',
#     'description': 'Husband, Father, Data Scientist, Python, R. For some places you have to be Lost in order to find them',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 273,
#     'friends_count': 546,
#     'listed_count': 1,
#     'created_at': 'Thu Dec 03 09:06:01 +0000 2009',
#     'favourites_count': 4314,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 2619,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1103968055221276673/Iycp8eST_normal.png',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1103968055221276673/Iycp8eST_normal.png',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/94290760/1552041575',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sat Aug 08 06:14:30 +0000 2020',
#     'id': 1291981089376858118,
#     'id_str': '1291981089376858118',
#     'text': 'Finally, I landed a job at a startup with a great salary and most likely will end up being a partner in the same co… https://t.co/cpGgos09gP',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/cpGgos09gP',
#        'expanded_url': 'https://twitter.com/i/web/status/1291981089376858118',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1158744568440868864,
#      'id_str': '1158744568440868864',
#      'name': 'Ankur Sinha',
#      'screen_name': 'SmokeyGunBarrel',
#      'location': 'Planet Earth',
#      'description': 'Self-Taught | Machine Learning | Deep Learning | Anime | Progressive Metal | EDM | Sci-Fi | 17 Star Eater',
#      'url': 'https://t.co/wmSYVXVfpU',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/wmSYVXVfpU',
#          'expanded_url': 'https://www.linkedin.com/in/ankur-sinha-8311931b',
#          'display_url': 'linkedin.com/in/ankur-sinha…',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 208,
#      'friends_count': 82,
#      'listed_count': 2,
#      'created_at': 'Tue Aug 06 14:20:08 +0000 2019',
#      'favourites_count': 637,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 743,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1276727485078450176/hwoPNbWd_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1276727485078450176/hwoPNbWd_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1158744568440868864/1592943347',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 99,
#     'favorite_count': 720,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 99,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Sat Aug 08 11:42:03 +0000 2020',
#    'id': 1292063522596302854,
#    'id_str': '1292063522596302854',
#    'text': '@shakir_za @DeepIndaba This is nothing short of faaantastic! #DeepLearning #Africa #4IR',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'DeepLearning', 'indices': [61, 74]},
#      {'text': 'Africa', 'indices': [75, 82]},
#      {'text': '4IR', 'indices': [83, 87]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'shakir_za',
#       'name': 'Shakir Mohamed',
#       'id': 476582730,
#       'id_str': '476582730',
#       'indices': [0, 10]},
#      {'screen_name': 'DeepIndaba',
#       'name': 'Deep Learning Indaba',
#       'id': 848799224854609920,
#       'id_str': '848799224854609920',
#       'indices': [11, 22]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
# ...
#     'in_reply_to_screen_name': None,
#     'user': {'id': 242460686,
#      'id_str': '242460686',
#      'name': 'Ashpot',
#      'screen_name': 'ashpotNG',
#      'location': 'Aba, Abia State Nigeria',
#      'description': 'Ashpot is a tech company specializing in professional IT Trainings, products and services.',
#      'url': 'https://t.co/JLhvRs9lfQ',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/JLhvRs9lfQ',
#          'expanded_url': 'https://www.ashpotmicrosystems.com',
#          'display_url': 'ashpotmicrosystems.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 223,
#      'friends_count': 39,
#      'listed_count': 1,
#      'created_at': 'Mon Jan 24 20:58:20 +0000 2011',
#      'favourites_count': 925,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 567,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '70818A',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1217762238158774277/D8A0KjQh_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1217762238158774277/D8A0KjQh_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/242460686/1544011192',
#      'profile_link_color': '07698A',
#      'profile_sidebar_border_color': 'FFFFFF',
#      'profile_sidebar_fill_color': 'DB7F41',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': {'id': '01307b1160a66303',
#      'url': 'https://api.twitter.com/1.1/geo/id/01307b1160a66303.json',
#      'place_type': 'city',
#      'name': 'Aba',
#      'full_name': 'Aba, Nigeria',
#      'country_code': 'NG',
#      'country': 'Nigeria',
#      'contained_within': [],
#      'bounding_box': {'type': 'Polygon',
#       'coordinates': [[[7.3116751, 5.0587562],
#         [7.4055676, 5.0587562],
#         [7.4055676, 5.1656501],
#         [7.3116751, 5.1656501]]]},
#      'attributes': {}},
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 13,
#     'favorite_count': 10,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 13,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Sat Aug 08 11:22:39 +0000 2020',
#    'id': 1292058639327539201,
#    'id_str': '1292058639327539201',
#    'text': 'RT @SmokeyGunBarrel: Finally, I landed a job at a startup with a great salary and most likely will end up being a partner in the same compa…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'SmokeyGunBarrel',
#       'name': 'Ankur Sinha',
#       'id': 1158744568440868864,
#       'id_str': '1158744568440868864',
#       'indices': [3, 19]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1269598947921866752,
#     'id_str': '1269598947921866752',
#     'name': 'Digital Dignified Solutions LTD',
#     'screen_name': 'DDS_LIMITED',
#     'location': '',
#     'description': 'Digitize your world',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 2,
#     'friends_count': 3,
#     'listed_count': 0,
#     'created_at': 'Sun Jun 07 11:56:15 +0000 2020',
#     'favourites_count': 0,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 3,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1269601971452948480/XP4AfECv_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1269601971452948480/XP4AfECv_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1269598947921866752/1591532749',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sat Aug 08 06:14:30 +0000 2020',
#     'id': 1291981089376858118,
#     'id_str': '1291981089376858118',
#     'text': 'Finally, I landed a job at a startup with a great salary and most likely will end up being a partner in the same co… https://t.co/cpGgos09gP',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/cpGgos09gP',
#        'expanded_url': 'https://twitter.com/i/web/status/1291981089376858118',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1158744568440868864,
#      'id_str': '1158744568440868864',
#      'name': 'Ankur Sinha',
#      'screen_name': 'SmokeyGunBarrel',
#      'location': 'Planet Earth',
#      'description': 'Self-Taught | Machine Learning | Deep Learning | Anime | Progressive Metal | EDM | Sci-Fi | 17 Star Eater',
#      'url': 'https://t.co/wmSYVXVfpU',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/wmSYVXVfpU',
#          'expanded_url': 'https://www.linkedin.com/in/ankur-sinha-8311931b',
#          'display_url': 'linkedin.com/in/ankur-sinha…',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 208,
#      'friends_count': 82,
#      'listed_count': 2,
#      'created_at': 'Tue Aug 06 14:20:08 +0000 2019',
#      'favourites_count': 637,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 743,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1276727485078450176/hwoPNbWd_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1276727485078450176/hwoPNbWd_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1158744568440868864/1592943347',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 99,
#     'favorite_count': 724,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 99,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Sat Aug 08 11:22:39 +0000 2020',
#    'id': 1292058638480052230,
#    'id_str': '1292058638480052230',
#    'text': 'RT @ashpotNG: A sneak peek into Ashtrid conversation flow!\n\nWhat the full 5 minutes conversation on \nhttps://t.co/XtxTkXnB1i\n\n#Ashtrid #mac…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'Ashtrid', 'indices': [126, 134]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'ashpotNG',
#       'name': 'Ashpot',
#       'id': 242460686,
#       'id_str': '242460686',
#       'indices': [3, 12]}],
#     'urls': [{'url': 'https://t.co/XtxTkXnB1i',
#       'expanded_url': 'https://youtu.be/Qx2qU5ds-Uw',
#       'display_url': 'youtu.be/Qx2qU5ds-Uw',
#       'indices': [101, 124]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 992943418052460544,
#     'id_str': '992943418052460544',
#     'name': 'Ricardo Vázquez',
#     'screen_name': 'ricardo_ik_ahau',
#     'location': 'Benito Juárez',
#     'description': 'Entender la realidad social para tranformarla',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 966,
#     'friends_count': 377,
#     'listed_count': 34,
#     'created_at': 'Sun May 06 01:45:33 +0000 2018',
#     'favourites_count': 907,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 238871,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/992945204918288390/1X6yiCkn_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/992945204918288390/1X6yiCkn_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Fri Aug 07 17:09:12 +0000 2020',
#     'id': 1291783462383493125,
#     'id_str': '1291783462383493125',
#     'text': 'A sneak peek into Ashtrid conversation flow!\n\nWhat the full 5 minutes conversation on \nhttps://t.co/XtxTkXnB1i… https://t.co/l04iEDFY1Y',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/XtxTkXnB1i',
#        'expanded_url': 'https://youtu.be/Qx2qU5ds-Uw',
#        'display_url': 'youtu.be/Qx2qU5ds-Uw',
#        'indices': [87, 110]},
#       {'url': 'https://t.co/l04iEDFY1Y',
#        'expanded_url': 'https://twitter.com/i/web/status/1291783462383493125',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [112, 135]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 242460686,
#      'id_str': '242460686',
#      'name': 'Ashpot',
#      'screen_name': 'ashpotNG',
#      'location': 'Aba, Abia State Nigeria',
#      'description': 'Ashpot is a tech company specializing in professional IT Trainings, products and services.',
#      'url': 'https://t.co/JLhvRs9lfQ',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/JLhvRs9lfQ',
#          'expanded_url': 'https://www.ashpotmicrosystems.com',
#          'display_url': 'ashpotmicrosystems.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 223,
#      'friends_count': 39,
#      'listed_count': 1,
#      'created_at': 'Mon Jan 24 20:58:20 +0000 2011',
#      'favourites_count': 925,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 567,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '70818A',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1217762238158774277/D8A0KjQh_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1217762238158774277/D8A0KjQh_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/242460686/1544011192',
#      'profile_link_color': '07698A',
#      'profile_sidebar_border_color': 'FFFFFF',
#      'profile_sidebar_fill_color': 'DB7F41',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': {'id': '01307b1160a66303',
#      'url': 'https://api.twitter.com/1.1/geo/id/01307b1160a66303.json',
#      'place_type': 'city',
#      'name': 'Aba',
#      'full_name': 'Aba, Nigeria',
#      'country_code': 'NG',
#      'country': 'Nigeria',
#      'contained_within': [],
#      'bounding_box': {'type': 'Polygon',
#       'coordinates': [[[7.3116751, 5.0587562],
#         [7.4055676, 5.0587562],
#         [7.4055676, 5.1656501],
#         [7.3116751, 5.1656501]]]},
#      'attributes': {}},
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 13,
#     'favorite_count': 10,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 13,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'}],
#  'search_metadata': {'completed_in': 0.141,
#   'max_id': 1292063957184688128,
#   'max_id_str': '1292063957184688128',
#   'next_results': '?max_id=1292058638480052229&q=%23DeepLearning&count=75&include_entities=1',
#   'query': '%23DeepLearning',
#   'refresh_url': '?since_id=1292063957184688128&q=%23DeepLearning&include_entities=1',
#   'count': 75,
#   'since_id': 0,
#   'since_id_str': '0'}}

# %% [markdown]
# Try adding a second parameter.  You can find the list here:  https://developer.twitter.com/en/docs/tweets/search/api-reference/get-search-tweets

# %%
search = '?q=%23DeepLearning&count=75&result=recent&lang=eu'

search_results = requests.get(base_url + search, auth=auth).json()
search_results
# Out:
# {'statuses': [{'created_at': 'Wed Aug 05 20:05:29 +0000 2020',
#    'id': 1291103051496001543,
#    'id_str': '1291103051496001543',
#    'text': 'ÑT»Uo^OÑ #deeplearning #cloudsecurity #crowdfunding #photography #pets #friends #piday #US https://t.co/VYM2YAppqS https://t.co/DXW6Jeq6sO',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'deeplearning', 'indices': [9, 22]},
#      {'text': 'cloudsecurity', 'indices': [23, 37]},
#      {'text': 'crowdfunding', 'indices': [38, 51]},
#      {'text': 'photography', 'indices': [52, 64]},
#      {'text': 'pets', 'indices': [65, 70]},
#      {'text': 'friends', 'indices': [71, 79]},
#      {'text': 'piday', 'indices': [80, 86]},
#      {'text': 'US', 'indices': [87, 90]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/VYM2YAppqS',
#       'expanded_url': 'https://vk.com/id15800296',
#       'display_url': 'vk.com/id15800296',
#       'indices': [91, 114]},
#      {'url': 'https://t.co/DXW6Jeq6sO',
#       'expanded_url': 'https://semigrot.wordpress.com/2020/08/05/ntuoon-deeplearning-cloudsecurity-crowdfunding-photography-pets-friends-piday-us-https-vk-com-id15800296/',
#       'display_url': 'semigrot.wordpress.com/2020/08/05/ntu…',
#       'indices': [115, 138]}]},
#    'metadata': {'iso_language_code': 'eu', 'result_type': 'recent'},
#    'source': '<a href="http://publicize.wp.com/" rel="nofollow">WordPress.com</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 2877754528,
#     'id_str': '2877754528',
#     'name': 'ququgaga',
#     'screen_name': 'ququgaga2',
#     'location': '',
#     'description': '#IGBT #PowerElectronics #MOSFET #SiC #Thyristor #Layout #Transistor #IC #Semiconductors #Schottky #Power #F4F #fb #followback #TFBJP #followall https://t.co/QecwMES3p3',
#     'url': 'https://t.co/QecwMES3p3',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/QecwMES3p3',
#         'expanded_url': 'http://goo.gl/k1ze9N',
#         'display_url': 'goo.gl/k1ze9N',
#         'indices': [0, 23]}]},
#      'description': {'urls': [{'url': 'https://t.co/QecwMES3p3',
#         'expanded_url': 'http://goo.gl/k1ze9N',
#         'display_url': 'goo.gl/k1ze9N',
#         'indices': [144, 167]}]}},
#     'protected': False,
#     'followers_count': 4697,
#     'friends_count': 4712,
#     'listed_count': 83,
#     'created_at': 'Sat Nov 15 08:27:05 +0000 2014',
#     'favourites_count': 0,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 98331,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/743476784772022273/NVdaaZUr_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/743476784772022273/NVdaaZUr_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2877754528/1507378910',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 2,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'eu'},
#   {'created_at': 'Mon Aug 03 13:30:21 +0000 2020',
#    'id': 1290278836261666816,
#    'id_str': '1290278836261666816',
#    'text': 'RT @semigleich: ÑwûzN-¾B #deeplearning #cloudsecurity #crowdfunding #photography #pets #friends #piday #US https://t.co/Zkz2GnfX8l https://…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'deeplearning', 'indices': [25, 38]},
#      {'text': 'cloudsecurity', 'indices': [39, 53]},
#      {'text': 'crowdfunding', 'indices': [54, 67]},
#      {'text': 'photography', 'indices': [68, 80]},
#      {'text': 'pets', 'indices': [81, 86]},
#      {'text': 'friends', 'indices': [87, 95]},
#      {'text': 'piday', 'indices': [96, 102]},
#      {'text': 'US', 'indices': [103, 106]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'semigleich',
#       'name': 'semigleichwww',
#       'id': 748871688813707265,
#       'id_str': '748871688813707265',
#       'indices': [3, 14]}],
#     'urls': [{'url': 'https://t.co/Zkz2GnfX8l',
#       'expanded_url': 'https://vk.com/id15800296',
#       'display_url': 'vk.com/id15800296',
#       'indices': [107, 130]}]},
#    'metadata': {'iso_language_code': 'eu', 'result_type': 'recent'},
#    'source': '<a href="http://www.massimilianovurro.com" rel="nofollow">Twitter Bot 2020_87</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 772361408956731392,
#     'id_str': '772361408956731392',
#     'name': 'Industry 4.0',
#     'screen_name': 'Manifattura40',
#     'location': 'Web',
#     'description': 'Trying to learn how simple is failing as bot using #Artificialintelligence #Blockchain #IoT #MachineLearning.',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 4468,
#     'friends_count': 4620,
#     'listed_count': 2296,
#     'created_at': 'Sun Sep 04 09:11:24 +0000 2016',
#     'favourites_count': 20,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 108073,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1041780951813169153/IMkHkS5S_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1041780951813169153/IMkHkS5S_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/772361408956731392/1537214977',
#     'profile_link_color': '1B95E0',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Mon Aug 03 13:29:24 +0000 2020',
#     'id': 1290278597014376449,
#     'id_str': '1290278597014376449',
#     'text': 'ÑwûzN-¾B #deeplearning #cloudsecurity #crowdfunding #photography #pets #friends #piday #US https://t.co/Zkz2GnfX8l https://t.co/wSOF1VmN8G',
#     'truncated': False,
#     'entities': {'hashtags': [{'text': 'deeplearning', 'indices': [9, 22]},
#       {'text': 'cloudsecurity', 'indices': [23, 37]},
#       {'text': 'crowdfunding', 'indices': [38, 51]},
#       {'text': 'photography', 'indices': [52, 64]},
#       {'text': 'pets', 'indices': [65, 70]},
#       {'text': 'friends', 'indices': [71, 79]},
#       {'text': 'piday', 'indices': [80, 86]},
#       {'text': 'US', 'indices': [87, 90]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/Zkz2GnfX8l',
#        'expanded_url': 'https://vk.com/id15800296',
#        'display_url': 'vk.com/id15800296',
#        'indices': [91, 114]},
#       {'url': 'https://t.co/wSOF1VmN8G',
#        'expanded_url': 'https://semidrehe.wordpress.com/2020/08/03/nwuzn-%c2%beb-deeplearning-cloudsecurity-crowdfunding-photography-pets-friends-piday-us-https-vk-com-id15800296/',
#        'display_url': 'semidrehe.wordpress.com/2020/08/03/nwu…',
#        'indices': [115, 138]}]},
#     'metadata': {'iso_language_code': 'eu', 'result_type': 'recent'},
#     'source': '<a href="http://publicize.wp.com/" rel="nofollow">WordPress.com</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 748871688813707265,
#      'id_str': '748871688813707265',
#      'name': 'semigleichwww',
#      'screen_name': 'semigleich',
#      'location': '',
#      'description': '#followback #TFBJP #follow #SYNOPSYS #SILVACO #HSPICE #VHDL #RTL #APD #GDSII #ESD #F4F #Autofollow #followall #openfollow',
#      'url': 'https://t.co/KNrQSGTD6g',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/KNrQSGTD6g',
#          'expanded_url': 'http://ow.ly/JuyL302S5Ye',
#          'display_url': 'ow.ly/JuyL302S5Ye',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 4460,
#      'friends_count': 4459,
#      'listed_count': 0,
#      'created_at': 'Fri Jul 01 13:31:38 +0000 2016',
#      'favourites_count': 0,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 90643,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/749873907214221312/YDvQrgVs_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/749873907214221312/YDvQrgVs_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/748871688813707265/1507379366',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 1,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'eu'},
#    'is_quote_status': False,
#    'retweet_count': 1,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'eu'},
#   {'created_at': 'Mon Aug 03 13:29:24 +0000 2020',
#    'id': 1290278597014376449,
#    'id_str': '1290278597014376449',
#    'text': 'ÑwûzN-¾B #deeplearning #cloudsecurity #crowdfunding #photography #pets #friends #piday #US https://t.co/Zkz2GnfX8l https://t.co/wSOF1VmN8G',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'deeplearning', 'indices': [9, 22]},
#      {'text': 'cloudsecurity', 'indices': [23, 37]},
#      {'text': 'crowdfunding', 'indices': [38, 51]},
#      {'text': 'photography', 'indices': [52, 64]},
#      {'text': 'pets', 'indices': [65, 70]},
#      {'text': 'friends', 'indices': [71, 79]},
#      {'text': 'piday', 'indices': [80, 86]},
#      {'text': 'US', 'indices': [87, 90]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/Zkz2GnfX8l',
#       'expanded_url': 'https://vk.com/id15800296',
#       'display_url': 'vk.com/id15800296',
#       'indices': [91, 114]},
#      {'url': 'https://t.co/wSOF1VmN8G',
#       'expanded_url': 'https://semidrehe.wordpress.com/2020/08/03/nwuzn-%c2%beb-deeplearning-cloudsecurity-crowdfunding-photography-pets-friends-piday-us-https-vk-com-id15800296/',
#       'display_url': 'semidrehe.wordpress.com/2020/08/03/nwu…',
#       'indices': [115, 138]}]},
#    'metadata': {'iso_language_code': 'eu', 'result_type': 'recent'},
#    'source': '<a href="http://publicize.wp.com/" rel="nofollow">WordPress.com</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 748871688813707265,
#     'id_str': '748871688813707265',
#     'name': 'semigleichwww',
#     'screen_name': 'semigleich',
#     'location': '',
#     'description': '#followback #TFBJP #follow #SYNOPSYS #SILVACO #HSPICE #VHDL #RTL #APD #GDSII #ESD #F4F #Autofollow #followall #openfollow',
#     'url': 'https://t.co/KNrQSGTD6g',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/KNrQSGTD6g',
#         'expanded_url': 'http://ow.ly/JuyL302S5Ye',
#         'display_url': 'ow.ly/JuyL302S5Ye',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 4460,
#     'friends_count': 4459,
#     'listed_count': 0,
#     'created_at': 'Fri Jul 01 13:31:38 +0000 2016',
#     'favourites_count': 0,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 90643,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/749873907214221312/YDvQrgVs_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/749873907214221312/YDvQrgVs_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/748871688813707265/1507379366',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 1,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'eu'}],
#  'search_metadata': {'completed_in': 0.047,
#   'max_id': 1291103051496001543,
#   'max_id_str': '1291103051496001543',
#   'next_results': '?max_id=1290278597014376448&q=%23DeepLearning&lang=eu&count=75&include_entities=1',
#   'query': '%23DeepLearning',
#   'refresh_url': '?since_id=1291103051496001543&q=%23DeepLearning&lang=eu&include_entities=1',
#   'count': 75,
#   'since_id': 0,
#   'since_id_str': '0'}}

# %% [markdown]
# ## Section 3: Searching Users

# %% [markdown]
# The last section of the API you'll need to get the hang of before you're let loose is the users API, which allows you to search for users and get their followers, friends, etc, as opposed to tweets which fit a particular criteria.  This part is pretty similar to the advanced lab in class 3, so if you saw how that worked then you shouldn't need much instruction.
#
# But if you're seeing this with fresh eyes, you'll want to spend 15-20 minutes to make sure you understand this part.
#
# Official documentation can be found here:  https://developer.twitter.com/en/docs/accounts-and-users/follow-search-get-users/overview
#
# So, as an example, if you want to get a list of someone's followers, you use the base url `https://api.twitter.com/1.1/followers/list.json` and then enter your query string to get a list of that person's followers.
#
# List of parameters to use can be found here:  https://developer.twitter.com/en/docs/accounts-and-users/follow-search-get-users/api-reference/get-followers-list
#
# One possible parameter to use is `screen_name`, so if you wanted to get a list of someone's followers based on their screen name (the handle that begins with an @), then you would set up your API call to look something like:
#
# `https://api.twitter.com/1.1/followers/list.json?screen_name=persons_screenname`
#
# Note that you exclude the `@`.
#
# **Your turn:** Pull in the list of General Assembly's followers.  General Assembly's handle is `@GA`.
#
# Note that this won't return the whole list of GA's users.  If you want to do that you have to use cursoring:  https://developer.twitter.com/en/docs/basics/cursoring.  This is the topic of your bonus assignment.

# %%
# swap followers for friends to search for who the user is following
user_base_url = 'https://api.twitter.com/1.1/followers/list.json'
search = '?screen_name=GA'

search_results = requests.get(user_base_url + search, auth=auth).json()
search_results
# Out:
# {'users': [{'id': 1292055415136583681,
#    'id_str': '1292055415136583681',
#    'name': 'Mayola Tyler',
#    'screen_name': 'tyler_mayola',
#    'location': '',
#    'description': 'Total explorer. Hipster-friendly entrepreneur. Amateur analyst. Troublemaker. Internet ninja.',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 0,
#    'friends_count': 11,
#    'listed_count': 0,
#    'created_at': 'Sat Aug 08 11:09:55 +0000 2020',
#    'favourites_count': 0,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 0,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1292055563250077696/IA2Bo6bh_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1292055563250077696/IA2Bo6bh_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 1030536043148259328,
#    'id_str': '1030536043148259328',
#    'name': 'Elias',
#    'screen_name': 'Elias60960250',
#    'location': 'Addis Ababa',
#    'description': '',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 1,
#    'friends_count': 38,
#    'listed_count': 0,
#    'created_at': 'Fri Aug 17 19:25:13 +0000 2018',
#    'favourites_count': 128,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 37,
#    'lang': None,
#    'status': {'created_at': 'Mon Apr 22 22:16:11 +0000 2019',
#     'id': 1120451257745981440,
#     'id_str': '1120451257745981440',
#     'text': '@StumblerFunny @StumblerTop Why is this funny?',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'StumblerFunny',
#        'name': 'Stumbler USA',
#        'id': 1112632763755032577,
#        'id_str': '1112632763755032577',
#        'indices': [0, 14]},
#       {'screen_name': 'StumblerTop',
#        'name': 'Stumbler Top',
#        'id': 345811633,
#        'id_str': '345811633',
#        'indices': [15, 27]}],
#      'urls': []},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': 1120432420011085824,
#     'in_reply_to_status_id_str': '1120432420011085824',
#     'in_reply_to_user_id': 1112632763755032577,
#     'in_reply_to_user_id_str': '1112632763755032577',
#     'in_reply_to_screen_name': 'StumblerFunny',
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 0,
#     'favorite_count': 2,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1225149645137072134/-A_HXCM-_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1225149645137072134/-A_HXCM-_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 97211785,
#    'id_str': '97211785',
#    'name': 'Marco Ogliengo',
#    'screen_name': 'mogliengo',
#    'location': 'Milano, Italy',
#    'description': '',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 80,
#    'friends_count': 113,
#    'listed_count': 0,
#    'created_at': 'Wed Dec 16 13:47:31 +0000 2009',
#    'favourites_count': 31,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 13,
#    'lang': None,
#    'status': {'created_at': 'Sat May 16 18:58:24 +0000 2020',
#     'id': 1261732753168650245,
#     'id_str': '1261732753168650245',
#     'text': 'RT @DennisHong17: Ecommerce Penetration https://t.co/SDnMggQrJz',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'DennisHong17',
#        'name': 'Dennis Hong',
#        'id': 1125462195494686720,
#        'id_str': '1125462195494686720',
#        'indices': [3, 16]}],
#      'urls': [],
#      'media': [{'id': 1261492528186036226,
#        'id_str': '1261492528186036226',
#        'indices': [40, 63],
#        'media_url': 'http://pbs.twimg.com/media/EYG4xU1WkAIevtD.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/EYG4xU1WkAIevtD.jpg',
#        'url': 'https://t.co/SDnMggQrJz',
#        'display_url': 'pic.twitter.com/SDnMggQrJz',
#        'expanded_url': 'https://twitter.com/DennisHong17/status/1261492532690763777/photo/1',
#        'type': 'photo',
#        'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'small': {'w': 680, 'h': 439, 'resize': 'fit'},
#         'medium': {'w': 791, 'h': 511, 'resize': 'fit'},
#         'large': {'w': 791, 'h': 511, 'resize': 'fit'}},
#        'source_status_id': 1261492532690763777,
#        'source_status_id_str': '1261492532690763777',
#        'source_user_id': 1125462195494686720,
#        'source_user_id_str': '1125462195494686720'}]},
#     'extended_entities': {'media': [{'id': 1261492528186036226,
#        'id_str': '1261492528186036226',
#        'indices': [40, 63],
#        'media_url': 'http://pbs.twimg.com/media/EYG4xU1WkAIevtD.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/EYG4xU1WkAIevtD.jpg',
#        'url': 'https://t.co/SDnMggQrJz',
#        'display_url': 'pic.twitter.com/SDnMggQrJz',
#        'expanded_url': 'https://twitter.com/DennisHong17/status/1261492532690763777/photo/1',
#        'type': 'photo',
#        'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'small': {'w': 680, 'h': 439, 'resize': 'fit'},
#         'medium': {'w': 791, 'h': 511, 'resize': 'fit'},
#         'large': {'w': 791, 'h': 511, 'resize': 'fit'}},
#        'source_status_id': 1261492532690763777,
#        'source_status_id_str': '1261492532690763777',
#        'source_user_id': 1125462195494686720,
#        'source_user_id_str': '1125462195494686720'}]},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'retweeted_status': {'created_at': 'Sat May 16 03:03:51 +0000 2020',
#      'id': 1261492532690763777,
#      'id_str': '1261492532690763777',
#      'text': 'Ecommerce Penetration https://t.co/SDnMggQrJz',
#      'truncated': False,
#      'entities': {'hashtags': [],
#       'symbols': [],
#       'user_mentions': [],
#       'urls': [],
#       'media': [{'id': 1261492528186036226,
#         'id_str': '1261492528186036226',
#         'indices': [22, 45],
#         'media_url': 'http://pbs.twimg.com/media/EYG4xU1WkAIevtD.jpg',
#         'media_url_https': 'https://pbs.twimg.com/media/EYG4xU1WkAIevtD.jpg',
#         'url': 'https://t.co/SDnMggQrJz',
#         'display_url': 'pic.twitter.com/SDnMggQrJz',
#         'expanded_url': 'https://twitter.com/DennisHong17/status/1261492532690763777/photo/1',
#         'type': 'photo',
#         'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#          'small': {'w': 680, 'h': 439, 'resize': 'fit'},
#          'medium': {'w': 791, 'h': 511, 'resize': 'fit'},
#          'large': {'w': 791, 'h': 511, 'resize': 'fit'}}}]},
#      'extended_entities': {'media': [{'id': 1261492528186036226,
#         'id_str': '1261492528186036226',
#         'indices': [22, 45],
#         'media_url': 'http://pbs.twimg.com/media/EYG4xU1WkAIevtD.jpg',
#         'media_url_https': 'https://pbs.twimg.com/media/EYG4xU1WkAIevtD.jpg',
#         'url': 'https://t.co/SDnMggQrJz',
#         'display_url': 'pic.twitter.com/SDnMggQrJz',
#         'expanded_url': 'https://twitter.com/DennisHong17/status/1261492532690763777/photo/1',
#         'type': 'photo',
#         'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#          'small': {'w': 680, 'h': 439, 'resize': 'fit'},
#          'medium': {'w': 791, 'h': 511, 'resize': 'fit'},
#          'large': {'w': 791, 'h': 511, 'resize': 'fit'}}}]},
#      'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#      'in_reply_to_status_id': None,
#      'in_reply_to_status_id_str': None,
#      'in_reply_to_user_id': None,
#      'in_reply_to_user_id_str': None,
#      'in_reply_to_screen_name': None,
#      'geo': None,
#      'coordinates': None,
#      'place': None,
#      'contributors': None,
#      'is_quote_status': False,
#      'retweet_count': 148,
#      'favorite_count': 459,
#      'favorited': False,
#      'retweeted': False,
#      'possibly_sensitive': False,
#      'lang': 'fr'},
#     'is_quote_status': False,
#     'retweet_count': 148,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'fr'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/599682829291753472/M5I3an4A_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/599682829291753472/M5I3an4A_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 376406877,
#    'id_str': '376406877',
#    'name': 'gluix',
#    'screen_name': 'gluix1',
#    'location': 'Münster',
#    'description': 'MAKE NORMALITY NORMAL AGAIN. \nC#/Angular/Typescript/HTML5/SCSS/GIT/Blockchain/MECH-Keyboards/-Enthusiast, Rocker, Pirat, Blader, Held der Informatik...',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 51,
#    'friends_count': 527,
#    'listed_count': 0,
#    'created_at': 'Mon Sep 19 20:46:39 +0000 2011',
#    'favourites_count': 398,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 173,
#    'lang': None,
#    'status': {'created_at': 'Mon Mar 30 17:32:54 +0000 2020',
#     'id': 1244679007087603713,
#     'id_str': '1244679007087603713',
#     'text': 'RT @UK_Muenster: Wir suchen gesundete Corona-PatientInnen für Studie: Personen, die Corona-Infektion hatten und jetzt einen negativen Coron…',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'UK_Muenster',
#        'name': 'Uniklinik Münster',
#        'id': 3004024965,
#        'id_str': '3004024965',
#        'indices': [3, 15]}],
#      'urls': []},
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'retweeted_status': {'created_at': 'Sun Mar 29 09:32:13 +0000 2020',
#      'id': 1244195651254132736,
#      'id_str': '1244195651254132736',
#      'text': 'Wir suchen gesundete Corona-PatientInnen für Studie: Personen, die Corona-Infektion hatten und jetzt einen negative… https://t.co/Ec3m97bQMV',
#      'truncated': True,
#      'entities': {'hashtags': [],
#       'symbols': [],
#       'user_mentions': [],
#       'urls': [{'url': 'https://t.co/Ec3m97bQMV',
#         'expanded_url': 'https://twitter.com/i/web/status/1244195651254132736',
#         'display_url': 'twitter.com/i/web/status/1…',
#         'indices': [117, 140]}]},
#      'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#      'in_reply_to_status_id': None,
#      'in_reply_to_status_id_str': None,
#      'in_reply_to_user_id': None,
#      'in_reply_to_user_id_str': None,
#      'in_reply_to_screen_name': None,
#      'geo': None,
#      'coordinates': None,
#      'place': None,
#      'contributors': None,
#      'is_quote_status': False,
#      'retweet_count': 1416,
#      'favorite_count': 905,
#      'favorited': False,
#      'retweeted': False,
#      'possibly_sensitive': False,
#      'lang': 'de'},
#     'is_quote_status': False,
#     'retweet_count': 1416,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'de'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'DEDEDE',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/3228335013/3ee0a616a2daf1e13ac517a62abbc151_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/3228335013/3ee0a616a2daf1e13ac517a62abbc151_normal.png',
#    'profile_link_color': '747F82',
#    'profile_sidebar_border_color': '181A1E',
#    'profile_sidebar_fill_color': '252429',
#    'profile_text_color': '666666',
#    'profile_use_background_image': False,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 781845042394574848,
#    'id_str': '781845042394574848',
#    'name': 'Heather Howard',
#    'screen_name': 'HHoward2016',
#    'location': 'Houston, TX',
#    'description': 'Wife, mom, dog lover, and 7th grade ELA teacher. Amazon Wishlist: https://t.co/v5CZVftjGx #clearthelists\n🦅🇺🇸',
#    'url': None,
#    'entities': {'description': {'urls': [{'url': 'https://t.co/v5CZVftjGx',
#        'expanded_url': 'https://amzn.to/38BXxEJ',
#        'display_url': 'amzn.to/38BXxEJ',
#        'indices': [66, 89]}]}},
#    'protected': False,
#    'followers_count': 2088,
#    'friends_count': 4990,
#    'listed_count': 11,
#    'created_at': 'Fri Sep 30 13:15:58 +0000 2016',
#    'favourites_count': 3642,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 1627,
#    'lang': None,
#    'status': {'created_at': 'Sat Aug 08 03:09:24 +0000 2020',
#     'id': 1291934508799926272,
#     'id_str': '1291934508799926272',
#     'text': '@CathyHolladay1 @HHoward2016',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'CathyHolladay1',
#        'name': 'Cathy Holladay',
#        'id': 787981196,
#        'id_str': '787981196',
#        'indices': [0, 15]},
#       {'screen_name': 'HHoward2016',
#        'name': 'Heather Howard',
#        'id': 781845042394574848,
#        'id_str': '781845042394574848',
#        'indices': [16, 28]}],
#      'urls': []},
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'in_reply_to_status_id': 1291911728935112711,
#     'in_reply_to_status_id_str': '1291911728935112711',
#     'in_reply_to_user_id': 787981196,
#     'in_reply_to_user_id_str': '787981196',
#     'in_reply_to_screen_name': 'CathyHolladay1',
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 0,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'und'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1270389224651579395/r7EKaZmw_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1270389224651579395/r7EKaZmw_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/781845042394574848/1591719484',
#    'profile_link_color': 'E81C4F',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 1105584574216704011,
#    'id_str': '1105584574216704011',
#    'name': 'Crypto Cantabria',
#    'screen_name': 'CryptoCantabria',
#    'location': '',
#    'description': 'Primera escuela de formación de Cantabria especializada en el uso de las cryptomonedas',
#    'url': 'https://t.co/uuWTKP5frz',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/uuWTKP5frz',
#        'expanded_url': 'http://www.cryptocan.es',
#        'display_url': 'cryptocan.es',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 203,
#    'friends_count': 783,
#    'listed_count': 2,
#    'created_at': 'Tue Mar 12 21:41:18 +0000 2019',
#    'favourites_count': 197,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 69,
#    'lang': None,
#    'status': {'created_at': 'Fri Aug 07 22:48:42 +0000 2020',
#     'id': 1291868900754432001,
#     'id_str': '1291868900754432001',
#     'text': '@barrysilbert @Grayscale @nitWitty It seems incredible to us what you are doing, it is essential to disseminate and train.',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'barrysilbert',
#        'name': 'Barry Silbert',
#        'id': 396045469,
#        'id_str': '396045469',
#        'indices': [0, 13]},
#       {'screen_name': 'Grayscale',
#        'name': 'Grayscale',
#        'id': 2800345565,
#        'id_str': '2800345565',
#        'indices': [14, 24]},
#       {'screen_name': 'nitWitty',
#        'name': 'Arnold, Marissa',
#        'id': 17472882,
#        'id_str': '17472882',
#        'indices': [25, 34]}],
#      'urls': []},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': 1291710737291841543,
#     'in_reply_to_status_id_str': '1291710737291841543',
#     'in_reply_to_user_id': 396045469,
#     'in_reply_to_user_id_str': '396045469',
#     'in_reply_to_screen_name': 'barrysilbert',
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 0,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1105584726545498115/jUdlwSty_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1105584726545498115/jUdlwSty_normal.png',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1105584574216704011/1552502323',
#    'profile_link_color': 'FAB81E',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 18942864,
#    'id_str': '18942864',
#    'name': 'Ali Khayrallah',
#    'screen_name': 'alisk',
#    'location': 'California',
#    'description': 'Working away at the G’s of mobile. Technology trends, big picture, strategery. Question everything. Views my own, unencumbered by fact. Go Blue! Go AUB!',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 87,
#    'friends_count': 1329,
#    'listed_count': 2,
#    'created_at': 'Tue Jan 13 16:26:29 +0000 2009',
#    'favourites_count': 35,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 812,
#    'lang': None,
#    'status': {'created_at': 'Fri Aug 07 23:40:04 +0000 2020',
#     'id': 1291881828891025408,
#     'id_str': '1291881828891025408',
#     'text': '@Yozarian22 @JoannaHorrocks @EricTopol @Bob_Wachter 1- good for NZ. 2- it’s an isolated relatively large country wi… https://t.co/GxeziuDgyW',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'Yozarian22',
#        'name': 'Daniel Kaufman',
#        'id': 828649700593168384,
#        'id_str': '828649700593168384',
#        'indices': [0, 11]},
#       {'screen_name': 'JoannaHorrocks',
#        'name': 'Joanna Horrocks-Pashdag',
#        'id': 1184539123,
#        'id_str': '1184539123',
#        'indices': [12, 27]},
#       {'screen_name': 'EricTopol',
#        'name': 'Eric Topol',
#        'id': 86626845,
#        'id_str': '86626845',
#        'indices': [28, 38]},
#       {'screen_name': 'Bob_Wachter',
#        'name': 'Bob Wachter',
#        'id': 239210681,
#        'id_str': '239210681',
#        'indices': [39, 51]}],
#      'urls': [{'url': 'https://t.co/GxeziuDgyW',
#        'expanded_url': 'https://twitter.com/i/web/status/1291881828891025408',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': 1291800738516078592,
#     'in_reply_to_status_id_str': '1291800738516078592',
#     'in_reply_to_user_id': 828649700593168384,
#     'in_reply_to_user_id_str': '828649700593168384',
#     'in_reply_to_screen_name': 'Yozarian22',
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 0,
#     'favorite_count': 2,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/839963598533226497/JQdSDpTI_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/839963598533226497/JQdSDpTI_normal.jpg',
#    'profile_link_color': '1B95E0',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 1290342410048995333,
#    'id_str': '1290342410048995333',
#    'name': 'Queen 👸 Tiffany',
#    'screen_name': 'QueenTi62831950',
#    'location': '',
#    'description': 'Just I and my son',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 5,
#    'friends_count': 173,
#    'listed_count': 0,
#    'created_at': 'Mon Aug 03 17:43:50 +0000 2020',
#    'favourites_count': 2,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 0,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1290343364525723648/CJLjOVMq_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1290343364525723648/CJLjOVMq_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1290342410048995333/1596477315',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 17366048,
#    'id_str': '17366048',
#    'name': 'Amunategui - ViralML.com',
#    'screen_name': 'amunategui',
#    'location': 'Barcelona, Spain',
#    'description': 'Markets, Data, Crypto...\n\nAuthor of Monetizing ML, Python Web Work & The Little Book of Fundamental Indicators | https://t.co/jqhBo3iMj2 | https://t.co/S1vua3IlP2',
#    'url': 'https://t.co/S1vua3IlP2',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/S1vua3IlP2',
#        'expanded_url': 'http://ViralML.com',
#        'display_url': 'ViralML.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': [{'url': 'https://t.co/jqhBo3iMj2',
#        'expanded_url': 'http://FastML.io',
#        'display_url': 'FastML.io',
#        'indices': [113, 136]},
#       {'url': 'https://t.co/S1vua3IlP2',
#        'expanded_url': 'http://ViralML.com',
#        'display_url': 'ViralML.com',
#        'indices': [139, 162]}]}},
#    'protected': False,
#    'followers_count': 11970,
#    'friends_count': 12593,
#    'listed_count': 53,
#    'created_at': 'Thu Nov 13 14:48:01 +0000 2008',
#    'favourites_count': 5484,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 9623,
#    'lang': None,
#    'status': {'created_at': 'Sat Aug 08 11:11:01 +0000 2020',
#     'id': 1292055710822539264,
#     'id_str': '1292055710822539264',
#     'text': 'Free class: Learn to decipher the markets with Python. ❤️♻️Re-tweet, sign-up for my newsletter and get my class fre… https://t.co/Z0KVCyzfFM',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/Z0KVCyzfFM',
#        'expanded_url': 'https://twitter.com/i/web/status/1292055710822539264',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'source': '<a href="https://buffer.com" rel="nofollow">Buffer</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 1,
#     'favorite_count': 1,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1211590718181060609/TuRRSsqd_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1211590718181060609/TuRRSsqd_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/17366048/1582531253',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 1273311788432588802,
#    'id_str': '1273311788432588802',
#    'name': 'Cheri K Hric',
#    'screen_name': 'k_hric',
#    'location': '',
#    'description': 'Working hard & having fun.',
#    'url': 'https://t.co/cuuF0n5Pz6',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/cuuF0n5Pz6',
#        'expanded_url': 'https://sites.google.com/escalent.co/audience/eaudience-info-home',
#        'display_url': 'sites.google.com/escalent.co/au…',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 14,
#    'friends_count': 126,
#    'listed_count': 0,
#    'created_at': 'Wed Jun 17 17:49:40 +0000 2020',
#    'favourites_count': 10,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 8,
#    'lang': None,
#    'status': {'created_at': 'Thu Aug 06 17:13:13 +0000 2020',
#     'id': 1291422086074896384,
#     'id_str': '1291422086074896384',
#     'text': 'RT @ishabazz: It’s day 6 of the #DevsPayItForward initiative supporting @BlackGirlsCode. Read more on the blog: https://t.co/8Bkyc9sQ2c. ht…',
#     'truncated': False,
#     'entities': {'hashtags': [{'text': 'DevsPayItForward',
#        'indices': [32, 49]}],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'ishabazz',
#        'name': '\uf8ffIsh',
#        'id': 28814082,
#        'id_str': '28814082',
#        'indices': [3, 12]},
#       {'screen_name': 'BlackGirlsCode',
#        'name': 'Black Girls CODE',
#        'id': 291814511,
#        'id_str': '291814511',
#        'indices': [72, 87]}],
#      'urls': [{'url': 'https://t.co/8Bkyc9sQ2c',
#        'expanded_url': 'https://bit.ly/DevsPayItForward',
#        'display_url': 'bit.ly/DevsPayItForwa…',
#        'indices': [112, 135]}]},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'retweeted_status': {'created_at': 'Thu Aug 06 14:17:49 +0000 2020',
#      'id': 1291377943818559496,
#      'id_str': '1291377943818559496',
#      'text': 'It’s day 6 of the #DevsPayItForward initiative supporting @BlackGirlsCode. Read more on the blog:… https://t.co/NTtEIIxyOL',
#      'truncated': True,
#      'entities': {'hashtags': [{'text': 'DevsPayItForward',
#         'indices': [18, 35]}],
#       'symbols': [],
#       'user_mentions': [{'screen_name': 'BlackGirlsCode',
#         'name': 'Black Girls CODE',
#         'id': 291814511,
#         'id_str': '291814511',
#         'indices': [58, 73]}],
#       'urls': [{'url': 'https://t.co/NTtEIIxyOL',
#         'expanded_url': 'https://twitter.com/i/web/status/1291377943818559496',
#         'display_url': 'twitter.com/i/web/status/1…',
#         'indices': [99, 122]}]},
#      'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#      'in_reply_to_status_id': None,
#      'in_reply_to_status_id_str': None,
#      'in_reply_to_user_id': None,
#      'in_reply_to_user_id_str': None,
#      'in_reply_to_screen_name': None,
#      'geo': None,
#      'coordinates': None,
#      'place': None,
#      'contributors': None,
#      'is_quote_status': False,
#      'retweet_count': 16,
#      'favorite_count': 18,
#      'favorited': False,
#      'retweeted': False,
#      'possibly_sensitive': False,
#      'lang': 'en'},
#     'is_quote_status': False,
#     'retweet_count': 16,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1273312018901204995/bKBvjZDD_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1273312018901204995/bKBvjZDD_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1273311788432588802/1593626343',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 542020468,
#    'id_str': '542020468',
#    'name': 'SonderMind',
#    'screen_name': 'SonderMind',
#    'location': 'Denver, CO',
#    'description': 'Therapy isn’t always easy. But finding it should be. SonderMind will help you find a licensed therapist who is available in-person or for video sessions.',
#    'url': 'https://t.co/Pp2HYr0gZf',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/Pp2HYr0gZf',
#        'expanded_url': 'http://sondermind.com',
#        'display_url': 'sondermind.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 1037,
#    'friends_count': 713,
#    'listed_count': 27,
#    'created_at': 'Sat Mar 31 22:05:09 +0000 2012',
#    'favourites_count': 1863,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 2051,
#    'lang': None,
#    'status': {'created_at': 'Fri Aug 07 20:03:01 +0000 2020',
#     'id': 1291827205752881152,
#     'id_str': '1291827205752881152',
#     'text': "Sure, you've heard of professional organizers,\xa0but have you heard of professional organizers who use a psychology-c… https://t.co/3pZ6Udj9wI",
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/3pZ6Udj9wI',
#        'expanded_url': 'https://twitter.com/i/web/status/1291827205752881152',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'source': '<a href="http://www.hubspot.com/" rel="nofollow">HubSpot</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 0,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F4FC0A',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1278340703764967426/kzHIgozp_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1278340703764967426/kzHIgozp_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/542020468/1584628881',
#    'profile_link_color': 'F79C7A',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 26254194,
#    'id_str': '26254194',
#    'name': 'Bree',
#    'screen_name': 'freetobebree',
#    'location': 'New Jersey',
#    'description': "Maybe she's born with it, maybe it's Quarantine",
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 334,
#    'friends_count': 418,
#    'listed_count': 15,
#    'created_at': 'Tue Mar 24 15:11:23 +0000 2009',
#    'favourites_count': 202,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 19562,
#    'lang': None,
#    'status': {'created_at': 'Fri Aug 07 18:03:51 +0000 2020',
#     'id': 1291797214508056576,
#     'id_str': '1291797214508056576',
#     'text': 'RT @KamalaHarris: Listen to the scientists and wear a mask.',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'KamalaHarris',
#        'name': 'Kamala Harris',
#        'id': 30354991,
#        'id_str': '30354991',
#        'indices': [3, 16]}],
#      'urls': []},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'retweeted_status': {'created_at': 'Fri Aug 07 17:28:01 +0000 2020',
#      'id': 1291788200277663746,
#      'id_str': '1291788200277663746',
#      'text': 'Listen to the scientists and wear a mask.',
#      'truncated': False,
#      'entities': {'hashtags': [],
#       'symbols': [],
#       'user_mentions': [],
#       'urls': []},
#      'source': '<a href="https://sproutsocial.com" rel="nofollow">Sprout Social</a>',
#      'in_reply_to_status_id': None,
#      'in_reply_to_status_id_str': None,
#      'in_reply_to_user_id': None,
#      'in_reply_to_user_id_str': None,
#      'in_reply_to_screen_name': None,
#      'geo': None,
#      'coordinates': None,
#      'place': None,
#      'contributors': None,
#      'is_quote_status': False,
#      'retweet_count': 12353,
#      'favorite_count': 85807,
#      'favorited': False,
#      'retweeted': False,
#      'lang': 'en'},
#     'is_quote_status': False,
#     'retweet_count': 12353,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'B8AC92',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme10/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme10/bg.gif',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1159908807918718977/p06BtKOx_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1159908807918718977/p06BtKOx_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/26254194/1572359161',
#    'profile_link_color': 'FAB81E',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'CE2D33',
#    'profile_text_color': '8A6960',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 14338572,
#    'id_str': '14338572',
#    'name': 'David Hoang',
#    'screen_name': 'davidhoang',
#    'location': 'California, USA',
#    'description': 'Designer, educator, and startup advisor. Director of Design @webflow + Instructor @GA. Before: @onemedical @blackpixel @htc @exacttarget. He/him.',
#    'url': 'https://t.co/imxh9aTS2D',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/imxh9aTS2D',
#        'expanded_url': 'http://davidhoang.com',
#        'display_url': 'davidhoang.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 10570,
#    'friends_count': 955,
#    'listed_count': 574,
#    'created_at': 'Wed Apr 09 03:17:33 +0000 2008',
#    'favourites_count': 48740,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 108095,
#    'lang': None,
#    'status': {'created_at': 'Sat Aug 08 06:52:05 +0000 2020',
#     'id': 1291990550334201856,
#     'id_str': '1291990550334201856',
#     'text': '@micaandreea @AlxSavage So funny, I was going to tweet to introduce you two because you’re both awesome—already one step ahead of me!',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'micaandreea',
#        'name': 'Mica Andreea 🏳️\u200d🌈 💻',
#        'id': 895308963163582465,
#        'id_str': '895308963163582465',
#        'indices': [0, 12]},
#       {'screen_name': 'AlxSavage',
#        'name': 'Alex',
#        'id': 4950721,
#        'id_str': '4950721',
#        'indices': [13, 23]}],
#      'urls': []},
#     'source': '<a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>',
#     'in_reply_to_status_id': 1291988544827936768,
#     'in_reply_to_status_id_str': '1291988544827936768',
#     'in_reply_to_user_id': 895308963163582465,
#     'in_reply_to_user_id_str': '895308963163582465',
#     'in_reply_to_screen_name': 'micaandreea',
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 0,
#     'favorite_count': 1,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'FFFFFF',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1248438525877350400/4ytt99Ba_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1248438525877350400/4ytt99Ba_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/14338572/1587575727',
#    'profile_link_color': '009999',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'BABABA',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 171874609,
#    'id_str': '171874609',
#    'name': 'Tothemoon🌈G43TENJXHAGE⭕',
#    'screen_name': 'BBACKMAL',
#    'location': '35.8714354,128.601445',
#    'description': '●Korean Veterinarian ●Blockchain & Crypto Asset ●Community Manager_KOREOS & VIGOR-kr\n\n#EOS #EOSIO #IBC #VOICE #DID #SSI #VIGOR #VIGORPROTOCOL #DeFi #DAC',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 245,
#    'friends_count': 1469,
#    'listed_count': 7,
#    'created_at': 'Wed Jul 28 11:26:36 +0000 2010',
#    'favourites_count': 7954,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 5782,
#    'lang': None,
#    'status': {'created_at': 'Sat Aug 08 08:20:44 +0000 2020',
#     'id': 1292012856410378241,
#     'id_str': '1292012856410378241',
#     'text': 'RT @PaulESamson: #Bitcoin Supply Cut Due To Lost Keys And Burning - #BitcoinNews - https://t.co/o8MStb91qR',
#     'truncated': False,
#     'entities': {'hashtags': [{'text': 'Bitcoin', 'indices': [17, 25]},
#       {'text': 'BitcoinNews', 'indices': [68, 80]}],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'PaulESamson',
#        'name': 'PaulCrypto.com',
#        'id': 126159663,
#        'id_str': '126159663',
#        'indices': [3, 15]}],
#      'urls': [{'url': 'https://t.co/o8MStb91qR',
#        'expanded_url': 'https://paulcrypto.com/2020/08/08/bitcoin-supply-cut-due-to-lost-keys-and-burning/',
#        'display_url': 'paulcrypto.com/2020/08/08/bit…',
#        'indices': [83, 106]}]},
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'retweeted_status': {'created_at': 'Sat Aug 08 08:17:04 +0000 2020',
#      'id': 1292011936708689920,
#      'id_str': '1292011936708689920',
#      'text': '#Bitcoin Supply Cut Due To Lost Keys And Burning - #BitcoinNews - https://t.co/o8MStb91qR',
#      'truncated': False,
#      'entities': {'hashtags': [{'text': 'Bitcoin', 'indices': [0, 8]},
#        {'text': 'BitcoinNews', 'indices': [51, 63]}],
#       'symbols': [],
#       'user_mentions': [],
#       'urls': [{'url': 'https://t.co/o8MStb91qR',
#         'expanded_url': 'https://paulcrypto.com/2020/08/08/bitcoin-supply-cut-due-to-lost-keys-and-burning/',
#         'display_url': 'paulcrypto.com/2020/08/08/bit…',
#         'indices': [66, 89]}]},
#      'source': '<a href="https://paulcrypto.com" rel="nofollow">paulcrypto</a>',
#      'in_reply_to_status_id': None,
# ...
#     'text': 'RT @AsiwajuLerry: Don’t disappoint your parents because you want to impress your friends.',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'AsiwajuLerry',
#        'name': 'Duke of Ibadan 🀄️',
#        'id': 886124456099368960,
#        'id_str': '886124456099368960',
#        'indices': [3, 16]}],
#      'urls': []},
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'retweeted_status': {'created_at': 'Thu Apr 09 20:20:32 +0000 2020',
#      'id': 1248345072053227525,
#      'id_str': '1248345072053227525',
#      'text': 'Don’t disappoint your parents because you want to impress your friends.',
#      'truncated': False,
#      'entities': {'hashtags': [],
#       'symbols': [],
#       'user_mentions': [],
#       'urls': []},
#      'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#      'in_reply_to_status_id': None,
#      'in_reply_to_status_id_str': None,
#      'in_reply_to_user_id': None,
#      'in_reply_to_user_id_str': None,
#      'in_reply_to_screen_name': None,
#      'geo': None,
#      'coordinates': None,
#      'place': None,
#      'contributors': None,
#      'is_quote_status': False,
#      'retweet_count': 3652,
#      'favorite_count': 11669,
#      'favorited': False,
#      'retweeted': False,
#      'lang': 'en'},
#     'is_quote_status': False,
#     'retweet_count': 3652,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1291712128563449858/gz9qqcXV_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1291712128563449858/gz9qqcXV_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1089090234858516481/1589451587',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 1291689567637004289,
#    'id_str': '1291689567637004289',
#    'name': 'Huong Vu',
#    'screen_name': 'HuongVuQ',
#    'location': '',
#    'description': 'Classes & Workshops Producer @ General Assembly Singapore',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 4,
#    'friends_count': 40,
#    'listed_count': 0,
#    'created_at': 'Fri Aug 07 10:56:13 +0000 2020',
#    'favourites_count': 1,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 5,
#    'lang': None,
#    'status': {'created_at': 'Fri Aug 07 11:00:24 +0000 2020',
#     'id': 1291690650526597122,
#     'id_str': '1291690650526597122',
#     'text': "RT @GA_Singapore: And we'll start #MadeinSG2020 with a BANG 💥 with @SGInnovate ! Hear from #Singapore's digital leaders shaping policies, b…",
#     'truncated': False,
#     'entities': {'hashtags': [{'text': 'MadeinSG2020', 'indices': [34, 47]},
#       {'text': 'Singapore', 'indices': [91, 101]}],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'GA_Singapore',
#        'name': 'ga_singapore',
#        'id': 3154543549,
#        'id_str': '3154543549',
#        'indices': [3, 16]},
#       {'screen_name': 'SGInnovate',
#        'name': 'SGInnovate',
#        'id': 784548544329965568,
#        'id_str': '784548544329965568',
#        'indices': [67, 78]}],
#      'urls': []},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'retweeted_status': {'created_at': 'Tue Aug 04 08:32:29 +0000 2020',
#      'id': 1290566262527889409,
#      'id_str': '1290566262527889409',
#      'text': "And we'll start #MadeinSG2020 with a BANG 💥 with @SGInnovate ! Hear from #Singapore's digital leaders shaping polic… https://t.co/sTgiVR0rtW",
#      'truncated': True,
#      'entities': {'hashtags': [{'text': 'MadeinSG2020', 'indices': [16, 29]},
#        {'text': 'Singapore', 'indices': [73, 83]}],
#       'symbols': [],
#       'user_mentions': [{'screen_name': 'SGInnovate',
#         'name': 'SGInnovate',
#         'id': 784548544329965568,
#         'id_str': '784548544329965568',
#         'indices': [49, 60]}],
#       'urls': [{'url': 'https://t.co/sTgiVR0rtW',
#         'expanded_url': 'https://twitter.com/i/web/status/1290566262527889409',
#         'display_url': 'twitter.com/i/web/status/1…',
#         'indices': [117, 140]}]},
#      'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#      'in_reply_to_status_id': None,
#      'in_reply_to_status_id_str': None,
#      'in_reply_to_user_id': None,
#      'in_reply_to_user_id_str': None,
#      'in_reply_to_screen_name': None,
#      'geo': None,
#      'coordinates': None,
#      'place': None,
#      'contributors': None,
#      'is_quote_status': False,
#      'retweet_count': 2,
#      'favorite_count': 4,
#      'favorited': False,
#      'retweeted': False,
#      'possibly_sensitive': False,
#      'lang': 'en'},
#     'is_quote_status': False,
#     'retweet_count': 2,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1291689654912028677/T19qh9qR_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1291689654912028677/T19qh9qR_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 1290547880051085312,
#    'id_str': '1290547880051085312',
#    'name': 'Sara.UxUi',
#    'screen_name': 'Sara42799963',
#    'location': '',
#    'description': 'UX/UI design student',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 1,
#    'friends_count': 2,
#    'listed_count': 0,
#    'created_at': 'Tue Aug 04 07:19:37 +0000 2020',
#    'favourites_count': 0,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 3,
#    'lang': None,
#    'status': {'created_at': 'Fri Aug 07 10:52:17 +0000 2020',
#     'id': 1291688609536282630,
#     'id_str': '1291688609536282630',
#     'text': "Such week. I haven't slept more than 4 hours per day, and yet I'm not done with my slides, and I'm not ready for pr… https://t.co/g64j5guXvD",
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/g64j5guXvD',
#        'expanded_url': 'https://twitter.com/i/web/status/1291688609536282630',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 0,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1290548186109505543/G8W4OMaq_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1290548186109505543/G8W4OMaq_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 265908932,
#    'id_str': '265908932',
#    'name': 'Caroline Raw',
#    'screen_name': 'Caz_Raw',
#    'location': 'Manchester, England',
#    'description': 'Digital, content, communications in higher education. Passionate about digital accessibility #a11y. Really love cheeseburgers and football.',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 153,
#    'friends_count': 194,
#    'listed_count': 0,
#    'created_at': 'Mon Mar 14 10:02:12 +0000 2011',
#    'favourites_count': 11,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 484,
#    'lang': None,
#    'status': {'created_at': 'Wed Aug 05 07:05:39 +0000 2020',
#     'id': 1290906798019555329,
#     'id_str': '1290906798019555329',
#     'text': "@FundEverywhere @AbilityNet are the guys to talk to. I've seen lots of their speakers. So many amazing people working there.",
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'FundEverywhere',
#        'name': 'Fundraising Everywhere & Everywhere+',
#        'id': 1131192709727883264,
#        'id_str': '1131192709727883264',
#        'indices': [0, 15]},
#       {'screen_name': 'AbilityNet',
#        'name': 'AbilityNet',
#        'id': 166975353,
#        'id_str': '166975353',
#        'indices': [16, 27]}],
#      'urls': []},
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'in_reply_to_status_id': 1290537204448727040,
#     'in_reply_to_status_id_str': '1290537204448727040',
#     'in_reply_to_user_id': 1131192709727883264,
#     'in_reply_to_user_id_str': '1131192709727883264',
#     'in_reply_to_screen_name': 'FundEverywhere',
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 0,
#     'favorite_count': 1,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '131516',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/921132305426640896/0HnQ-tAS_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/921132305426640896/0HnQ-tAS_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/265908932/1559916885',
#    'profile_link_color': 'FF0000',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'EFEFEF',
#    'profile_text_color': '333333',
#    'profile_use_background_image': False,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 111485855,
#    'id_str': '111485855',
#    'name': 'Riley Gibbs',
#    'screen_name': 'rgibbs9',
#    'location': 'Lake Tahoe, NV',
#    'description': 'tech, software, design, travel.\n@EatThisMuch Software Eng\n@GA UXD Alum\n@UCLA Grad\nhe/him',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 107,
#    'friends_count': 546,
#    'listed_count': 0,
#    'created_at': 'Fri Feb 05 02:55:47 +0000 2010',
#    'favourites_count': 2216,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 591,
#    'lang': None,
#    'status': {'created_at': 'Fri Aug 07 17:12:19 +0000 2020',
#     'id': 1291784246319673344,
#     'id_str': '1291784246319673344',
#     'text': 'silver lining looking good today https://t.co/dYs2m7z3B7',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/dYs2m7z3B7',
#        'expanded_url': 'https://twitter.com/nypost/status/1291402028707721217',
#        'display_url': 'twitter.com/nypost/status/…',
#        'indices': [33, 56]}]},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': True,
#     'quoted_status_id': 1291402028707721217,
#     'quoted_status_id_str': '1291402028707721217',
#     'retweet_count': 0,
#     'favorite_count': 1,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/877295993120710656/Y-PXqLgU_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/877295993120710656/Y-PXqLgU_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'}],
#  'next_cursor': 1674343396299516238,
#  'next_cursor_str': '1674343396299516238',
#  'previous_cursor': 0,
#  'previous_cursor_str': '0',
#  'total_count': None}

# %% [markdown]
# ## Section 4: Functions

# %% [markdown]
# This section details the functions you have to write and turn in as part of your homework assignment.
#
# Please read the requirements carefully.
#
# **What you'll turn in:** A `.py` file with all of the functions written.  We should be able to load this into an IDE, run the file, and then call your functions to verify how and if they work. This file should also be properly commented so we can follow your line of reasoning.
#
# The functions you'll be prompted to write will be defined in the following ways:
#
#  - **name:** the name of the function
#  - **returns:** what the function should return
#  - **arguments:** arguments to include inside the function in order to specify how it should behave.
#
#  **Note:** The free API has limitations built into it, so this means from time-to-time you'll only be able to return some of the results from the API.  This is fine.  It's understood and recognized that your functions won't be able to return an entire list of someone's users or other such things, so as long as your work delivers the best it can under present circumstances you'll be in good shape.
#
#  **Other Note:** Every aspect of the API that you need to use can be found on either of these pages.
#
#  Search API:  https://developer.twitter.com/en/docs/tweets/search/api-reference/get-search-tweets
#
#  Users API: https://developer.twitter.com/en/docs/accounts-and-users/follow-search-get-users/api-reference
#
# **Remarks About Your Final Work**
#
#  - It's okay if you get stuck somewhere.  If there's one item that you can't figure out and it doesn't quite work right, it's probably best to move on and try other things.  Again, try and explain what you were looking to do.  You'll pass if you give an honest effort.
#  - There's potentially a lot of error handling you could do to verify user input is correct, but you can leave that alone for now.  Just make sure the core purpose of the function works the way it's supposed to.
#  - While you're working on this, it's possible you may bump into your API limits.  Keep this in mind if you have a function that's working, but 45 minutes later it doesn't and you haven't changed anything.  This usually means the data you're getting back from your API calls isn't what it's supposed to be because you've exhausted your limits. We won't hold you to double checking for all of this in your functions.
#  - In the file you turn in, make sure your requests are referencing your API tokens, so that way we can run your file right away.  Ie, make sure somewhere in your script you have a variable at the top that reads `tokens = OAuth1('token1', 'token2', 'token3', 'token4')` so it can be used for your requests inside the file.

# %% [markdown]
# ##### Function 1 (Required)

# %% [markdown]
# **Name:** `find_user`
#
# **Returns:** dictionary that represents user object returned by Twitter's API
#
# **Arguments:**
#  - `screen_name`: str, required; Twitter handle to search for.  **Can include the @ symbol.  The function should check for this and remove it if necessary.**
#  - `keys`: list, optional; list that contains keys to return about user object.  If not specified, then function should return the entire user object.  **These only need to be outer keys.** If they are keys nested within another key, you don't have to account for this.
#
# **To test:** We'll test your function in the following ways:
#
#  - `find_user('@GA')`
#  - `find_user('GA')`
#  - `find_user('GA', keys=['name', 'screen_name', 'followers_count', 'friends_count'])`

# %%
#function find_user: finds user specified in argument, can provide keys for additional information

import requests
from requests_oauthlib import OAuth1

base_url = 'https://api.twitter.com/1.1/account/verify_credentials.json'
# search = '?q='

user_base_url = 'https://api.twitter.com/1.1/users/lookup.json'
user_search = '?screen_name='

auth = OAuth1()

def find_user(user, keys=None):
    
    results = requests.get(user_base_url + user_search + user.replace('@',''), auth=auth).json()[0]

    if keys != None:
        reduced_results = {}
        for key in keys:
            reduced_results[key] = results[key]
        return reduced_results
    
    else:
        return results

# find_user('@GA', keys=['name', 'screen_name', 'followers_count', 'friends_count'])
find_user('@GA')
# Out:
# {'id': 170393291,
#  'id_str': '170393291',
#  'name': 'General Assembly',
#  'screen_name': 'GA',
#  'location': '',
#  'description': 'We transform careers and teams — including more than one third of the Fortune 100 — through dynamic courses in coding, data, design, and business.',
#  'url': 'https://t.co/YQeEXPxJ4H',
#  'entities': {'url': {'urls': [{'url': 'https://t.co/YQeEXPxJ4H',
#      'expanded_url': 'http://ga.co/Twitter',
#      'display_url': 'ga.co/Twitter',
#      'indices': [0, 23]}]},
#   'description': {'urls': []}},
#  'protected': False,
#  'followers_count': 165522,
#  'friends_count': 5417,
#  'listed_count': 3263,
#  'created_at': 'Sat Jul 24 18:19:59 +0000 2010',
#  'favourites_count': 36405,
#  'utc_offset': None,
#  'time_zone': None,
#  'geo_enabled': True,
#  'verified': True,
#  'statuses_count': 22756,
#  'lang': None,
#  'status': {'created_at': 'Sat Aug 08 17:27:02 +0000 2020',
#   'id': 1292150339995607045,
#   'id_str': '1292150339995607045',
#   'text': '5 benefits of coding that can be useful in other aspects of your life:\n✅ Problem solving\n✅ Attention to detail\n✅ La… https://t.co/6ydISO2O1M',
#   'truncated': True,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/6ydISO2O1M',
#      'expanded_url': 'https://twitter.com/i/web/status/1292150339995607045',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [117, 140]}]},
#   'source': '<a href="https://sproutsocial.com" rel="nofollow">Sprout Social</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 3,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  'contributors_enabled': False,
#  'is_translator': False,
#  'is_translation_enabled': False,
#  'profile_background_color': 'FFFFFF',
#  'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#  'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#  'profile_background_tile': True,
#  'profile_image_url': 'http://pbs.twimg.com/profile_images/1267818300416745472/A3qO4Fer_normal.jpg',
#  'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1267818300416745472/A3qO4Fer_normal.jpg',
#  'profile_banner_url': 'https://pbs.twimg.com/profile_banners/170393291/1480618900',
#  'profile_link_color': 'DE2233',
#  'profile_sidebar_border_color': 'FFFFFF',
#  'profile_sidebar_fill_color': 'FFFFFF',
#  'profile_text_color': '000000',
#  'profile_use_background_image': True,
#  'has_extended_profile': False,
#  'default_profile': False,
#  'default_profile_image': False,
#  'following': False,
#  'follow_request_sent': False,
#  'notifications': False,
#  'translator_type': 'none'}

# %%
url = 'https://api.twitter.com/1.1/account/verify_credentials.json'
search = '?q='

user_base_url = 'https://api.twitter.com/1.1/followers/list.json'
user_search = '?screen_name='

def find_user(user, keys=None):

        search_results = user_base_url + user_search + user.replace('@','')

        if keys != None:
            reduced_results = {}
            reduced_results = [key for key in keys]
            return reduced_results
        
        else:
            return search_results
    
# find_user('GA')
find_user('@GA', keys=['name', 'screen_name', 'followers_count', 'friends_count'])
# Out:
# ['name', 'screen_name', 'followers_count', 'friends_count']

# %% [markdown]
# ##### Function 2 (Required)

# %% [markdown]
# **Name:** `find_hashtag`
#
# **Returns:** list of data objects that contain information about each tweet that matches the hashtag provided as input.
#
# **Arguments:**
#  - `hashtag`: str, required; text to use as a hashtag search.
#  - `count`: int, optional; number of results to return
#  - `search_type`: str, optional; type of results to return.  should accept 3 different values:
#    - `mixed`:   return mix of most recent and most popular results
#    - `recent`:  return most recent results
#    - `popular`: return most popular results
#
# **Note:** User should **not** have to actually use the `#` character for the `hashtag` argument.  The function should check to see if it's there, and if not, add it in for them.
#
# **To Test:**  We'll check your function in the following ways:
#  - `find_hashtag('DataScience')`
#  - `find_hashtag('#DataScience')`
#  - `find_hashtag('#DataScience', count=100)`, and double check the length of the `statuses` key to make sure it contains the right amount of results.  **Note:** Due to the version of the API we're using, the number of results returned will **not** necessarily match the value passed into the `count` parameter.  So if you specify 50 and it only returns 45, you are likely still doing it correctly.
#  - `find_hashtag('#DataScience', search_type='recent/mixed/popular')`

# %% [markdown]
# ##### Function 3 (Required)

# %% [markdown]
# **Name:** `get_followers`
#
# **Returns:** list of data objects for each of the users followers, returning values for the `name`, `followers_count`, `friends_count`, and `screen_name` key for each user.
#
# **Arguments:**
#
#  - `screen_name`: str, required; Twitter handle to search for.  **Results should not depend on user inputting the @ symbol.**
#  - `keys`: list, required;  keys to return for each user.  default value: [`name`, `followers_count`, `friends_count`, `screen_name`]; if something else is listed, values for those keys should be returned
#  - `to_df`: bool, required; default value: False; if True, return results in a dataframe.  Every value provided in the `keys` argument should be its own column, with rows populated by the corresponding values for each one for every user.
#
# **To Test:** We'll test your functions in the following ways:
#
#  - `get_followers('@GA')`
#  - `get_followers('GA')`
#  - `get_followers('GA', keys=['name', 'followers_count'])`
#  - `get_followers('GA', keys=['name', 'followers_count'], to_df=True)`
#  - `get_followers('GA', to_df=True)`

# %%
#function find_user: finds user specified in argument, can provide keys for additional information

import requests
from requests_oauthlib import OAuth1

import pandas as pd

base_url = 'https://api.twitter.com/1.1/account/verify_credentials.json'

user_base_url = 'https://api.twitter.com/1.1/users/lookup.json'
user_search = '?screen_name='

auth = OAuth1()

def get_followers (screen_name, keys=None, to_df=False):
    
    results = requests.get(user_base_url + user_search + screen_name.replace('@',''), auth=auth).json()[0]
    
    if keys != None:
        reduced_results = {}
        for key in keys:
            reduced_results[key] = results[key]
        if to_df==True:
            df = pd.DataFrame(reduced_results,index=[0]) #setting index as 0 as pandas is enforcing an index
            return df
        else:
            return reduced_results
    
    else:
        if to_df==True:
            df = pd.DataFrame(results,index=[0]) #setting index as 0 as pandas is enforcing an index
            return df
        else:
            return results

get_followers('@GA', keys=['name', 'screen_name', 'followers_count', 'friends_count'], to_df=True)
# get_followers('@GA')
# get_followers('GA')
# get_followers('GA', keys=['name', 'followers_count'])
# get_followers('GA', keys=['name', 'followers_count'], to_df=True)
# get_followers('GA', to_df=True)
# Out:
#                name screen_name  followers_count  friends_count
# 0  General Assembly          GA           165523           5417

# %% [markdown]
# ##### Function 4 (Optional)

# %% [markdown]
# **Name:** `friends_of_friends`
#
# **Returns:** list of data objects for each user that two Twitter users have in common
#
# **Arguments:**
#
#  - `names`: list, required; list of two Twitter users to compare friends list with
#  - `keys`: list, optional; list of keys to return for information about each user.  Default value should be to return the entire data object.
#  - `to_df`: bool, required; default value: False; if True, returns results in a dataframe.
#
# **To Test:** We'll test your function in the following ways:
#
#  - `friends_of_friends(['Beyonce', 'MariahCarey'])`
#  - `friends_of_friends(['@Beyonce', '@MariahCarey'], to_df=True)`
#  - `friends_of_friends(['Beyonce', 'MariahCarey'], keys=['id', 'name'])`
#  - `friends_of_friends(['Beyonce', 'MariahCarey'], keys=['id', 'name'], to_df=True)`
#
# Each of these should return 3 results. (Assuming they haven't followed the same people since this was last written).
#
# **Hint:** The `id` key is the unique identifier for someone, so if you want to check if two people are the same this is the best way to do it.

# %% [markdown]
#  ##### Function 5 (Optional)

# %% [markdown]
# Rewrite the `friends_of_friends` function, except this time include an argument called `full_search`, which accepts a boolean value.  If set to `True`, use cursoring to cycle through the complete set of users for the users provided.
#
# The twitter API only returns a subset of users in your results to save bandwidth, so you have to cycle through multiple result sets to get all of the values.
#
# You can read more about how this works here:  https://developer.twitter.com/en/docs/basics/cursoring
#
# Basically you have to do a `while` loop to continually make a new request using the values stored in the `next_cursor` key as part of your next query string until there's nothing left to search.
#
# **Note:** We're using the free API, so we're operating under some limitations.  One of them being that you can only make 15 API calls in a 15 minute span to this portion of the API.  You can also only return up to 200 results per cursor, so this means you won't be able to completely search for everyone even if you set this up correctly.
#
# That's fine, just do what you can under the circumstances.
#
# **To Test:** To test your function, we'll run the following function calls:
#
#  - `friends_of_friends(['ezraklein', 'tylercowen'])` -- should return 4 results if you do an API call that returns 200 results
#  - `friends_of_friends(['ezraklein', 'tylercowen'], full_search=True)` -- should return 54 results if you do an API call that returns 200 results
#
# **Hint:** Chances are you will exhaust your API limits quite easily in this function depending on who you search for.  Depending on how you have things set up, this could cause error messages to arise when things are otherwise fine.  Remember in class 3 when we were getting those weird dictionaries back because our limits were used up?  We won't hold you accountable for handling this inside your function, although it could make some things easier for your own testing.
#
# Good luck!
