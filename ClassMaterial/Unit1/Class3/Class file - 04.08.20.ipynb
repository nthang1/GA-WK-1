# %%
pwd
# Out:
# '/Users/nerajthangarajah/GA-WK-1/ClassMaterial/Unit1/Class3'

# %%
num = num + 1
#is the same as 
num += 1
#you can replace + with / - etc.

# %%
import requests 
url = 'https://api.census.gov/data.json'
web_data = requests.get(url)

# %%
web_data
# Out:
# <Response [200]>

# %%
census_data = web_data.json()

# %%
census_data
# Out:
# {'@context': 'https://project-open-data.cio.gov/v1.1/schema/catalog.jsonld',
#  '@id': 'https://api.census.gov/data/1986/cbp.json',
#  '@type': 'dcat:Catalog',
#  'conformsTo': 'https://project-open-data.cio.gov/v1.1/schema',
#  'describedBy': 'https://project-open-data.cio.gov/v1.1/schema/catalog.json',
#  'dataset': [{'c_vintage': 1986,
#    'c_dataset': ['cbp'],
#    'c_geographyLink': 'https://api.census.gov/data/1986/cbp/geography.json',
#    'c_variablesLink': 'https://api.census.gov/data/1986/cbp/variables.json',
#    'c_tagsLink': 'https://api.census.gov/data/1986/cbp/tags.json',
#    'c_examplesLink': 'https://api.census.gov/data/1986/cbp/examples.json',
#    'c_groupsLink': 'https://api.census.gov/data/1986/cbp/groups.json',
#    'c_valuesLink': 'https://api.census.gov/data/1986/cbp/values.json',
#    'c_documentationLink': 'http://www.census.gov/developer/',
#    'c_isAggregate': True,
#    'c_isAvailable': True,
#    '@type': 'dcat:Dataset',
# ...

# %%
import pandas as pd
df = pd.DataFrame(census_data['dataset'])

# %%
github_url = 'https://api.github.com/users/nthang1/repos'
github_data = requests.get(github_url).json()

# %%
github_data
# Out:
# [{'id': 283306544,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyODMzMDY1NDQ=',
#   'name': 'GA-WK-1',
#   'full_name': 'nthang1/GA-WK-1',
#   'private': False,
#   'owner': {'login': 'nthang1',
#    'id': 42146333,
#    'node_id': 'MDQ6VXNlcjQyMTQ2MzMz',
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/42146333?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/nthang1',
#    'html_url': 'https://github.com/nthang1',
#    'followers_url': 'https://api.github.com/users/nthang1/followers',
#    'following_url': 'https://api.github.com/users/nthang1/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/nthang1/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/nthang1/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/nthang1/subscriptions',
#    'organizations_url': 'https://api.github.com/users/nthang1/orgs',
#    'repos_url': 'https://api.github.com/users/nthang1/repos',
# ...

# %%
pwd
# Out:
# '/Users/nerajthangarajah/GA-WK-1/ClassMaterial/Unit1/Class3'

# %%
cd Downloads/
# Out:
# /Users/nerajthangarajah/Downloads

# %%
with open ('DAT-07-28 Github Repos - Sheet1.csv') as f:
    csv_data = f.readlines()

# %%
csv_data
# Out:
# ['Name,Github Repo\n',
#  'Jonathan Bechtel,https://github.com/JonathanBechtel\n',
#  'Luki Elizalde,https://github.com/groovyluki\n',
#  'iuliana trufas,https://github.com/Yuliana-GitHub\n',
#  'Neraj Thangarajah,https://github.com/nthang1\n',
#  'Alina Urs,https://github.com/sprintkayaking\n',
#  'Ashleigh Grant,https://github.com/AshleighGrant\n',
#  'Nick Hudgell ,Https://github.com/nhudgell/GADS\n',
#  'Elisa Scagnetto,https://github.com/lisadt/es_repo280720']

# %%
# dictionary with information about General Assembly as a company
company_info = {
    'Name': 'General Assembly',
    'Categories': ['Education', 'Product Design', 'UX Design', 'Web Design', 'Web Development'],
    'Founded': 'Jan. 3, 2011',
    'Founders': ['Adam Pritzker', 'Brad Hargreaves', 'Jake Schwartz', 'Matthew Brimer'],
    'Operating Status': 'Active',
    'Funding Status': 'M&A',
    'Last Funding Type': 'Corporate Round',
    'Number of Employees': '501-1000',
    'Legal Name': 'General Assembly Space, Inc.',
    'Child Hubs': 'General Assembly Alumni Founded Companies',
    'Hub Tags': ['Pledge 1%'],
    'Funding Events': [{'Round': 'Series A', 'Date': 'Jan. 12, 2011', 'Amount': 1250000}, {'Round': 'Series B', 'Date': 'Feb. 11, 2012', 'Amount': 3750000}, {'Round': 'Series C', 'Date': 'Mar. 24, 2014', 'Amount': 12500000}]
}

# %%
pd.DataFrame(company_info)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-f671b0d9c387> in <module>
# ----> 1 pd.DataFrame(company_info)
#
# TypeError: 'list' object is not callable
